# %% [markdown]
# # Finding Similar Subject Nodes in a Neo4j Graph Database
#
# ## Overview
#
# This notebook explains the process of finding similar subject nodes (clinical trials) in a Neo4j graph database. It uses Neo4j’s Graph Data Science (GDS) library and the Node Similarity algorithm to calculate similarity scores based on shared relationships. This method is particularly useful in our case for clinical trial recommendations, where trials are compared based on conditions, drugs, or outcomes they share.

# %%
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /usr/local/lib/python3.11/dist-packages (5.27.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2024.2)

# %% [markdown]
# ### Step 1: Establish Connection to Neo4j  and view the already existing nodes
#
# Use the Neo4j Python driver to connect to the database:

# %%
from neo4j import GraphDatabase

# Connection details
URI = "neo4j://38.242.232.192:7687"
AUTH = ("nest", "neurons-newbie")

# Query to view existing nodes
query = """
MATCH (n)
RETURN n
LIMIT 10
"""

# Connect to the database and run the query
try:
    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        with driver.session() as session:
            result = session.run(query)

            # Process and print the nodes
            print("Nodes in the database:")
            for record in result:
                print(record["n"])  # Access the node data
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Nodes in the database:
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32961' labels=frozenset({'SubjectNode'}) properties={'name': 'NCT03821493'}>
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32962' labels=frozenset({'ObjectNode'}) properties={'name': 'Healthy Fed Participants'}>
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32963' labels=frozenset({'ObjectNode'}) properties={'name': 'Isavuconazole'}>
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32964' labels=frozenset({'ObjectNode'}) properties={'name': 'AUCinf of PF-06835919'}>
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32965' labels=frozenset({'ObjectNode'}) properties={'name': 'Maximum Observed Plasma Analyte Concentration'}>
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32966' labels=frozenset({'ObjectNode'}) properties={'name': 'BMI 18 to 32 kg/m2'}>
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32967' labels=frozenset({'ObjectNode'}) properties={'name': 'Body weight ≥ 45 kg'}>
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32968' labels=frozenset({'ObjectNode'}) properties={'name': 'diagnosed chronic heart failure'}>
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32969' labels=frozenset({'ObjectNode'}) properties={'name': 'hypersensitivity itraconazole'}>
# <Node element_id='4:4e1a6d5f-d162-4464-a50b-c8bfba1745ea:32970' labels=frozenset({'ObjectNode'}) properties={'name': 'Hepatitis B e Antigen Seroconversion'}>

# %% [markdown]
# Verifying total number of nodes and relationships in the database

# %%
# Queries to count nodes and relationships
query_nodes = "MATCH (n) RETURN COUNT(n) AS TotalNodes;"
query_relationships = "MATCH ()-[r]->() RETURN COUNT(r) AS TotalRelationships;"

try:
    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        with driver.session() as session:
            # Count nodes
            result_nodes = session.run(query_nodes)
            for record in result_nodes:
                print("Total Nodes in the Database:", record["TotalNodes"])

            # Count relationships
            result_relationships = session.run(query_relationships)
            for record in result_relationships:
                print("Total Relationships in the Database:", record["TotalRelationships"])
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Total Nodes in the Database: 17441
# Total Relationships in the Database: 39380

# %%
try:
    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        with driver.session() as session:
            result = session.run("CALL gds.graph.list()")

            # Processing and print the results
            for record in result:
                print(record)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated field from a procedure. ('schema' returned by 'gds.graph.list' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: 'CALL gds.graph.list()'
# <Record degreeDistribution={'min': 1, 'max': 536, 'p90': 9, 'p999': 157, 'p99': 29, 'p50': 2, 'p75': 6, 'p95': 12, 'mean': 4.515796112608222} graphName='clinicalTrialsGraph' database='neo4j' databaseLocation='local' memoryUsage='5115 KiB' sizeInBytes=5238717 nodeCount=17441 relationshipCount=78760 configuration={'relationshipProjection': {'RELATIONSHIP': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {}, 'type': 'RELATIONSHIP'}}, 'readConcurrency': 4, 'relationshipProperties': {}, 'nodeProperties': {}, 'jobId': '2baab3c5-039e-4d51-a0b0-c0dad0580fa3', 'nodeProjection': {'ObjectNode': {'label': 'ObjectNode', 'properties': {}}, 'SubjectNode': {'label': 'SubjectNode', 'properties': {}}}, 'logProgress': True, 'creationTime': neo4j.time.DateTime(2025, 1, 26, 15, 15, 29, 855750047, tzinfo=<UTC>), 'validateRelationships': False, 'sudo': False} density=0.0002589332633376274 creationTime=neo4j.time.DateTime(2025, 1, 26, 15, 15, 29, 855750047, tzinfo=<UTC>) modificationTime=neo4j.time.DateTime(2025, 1, 26, 15, 15, 29, 869712652, tzinfo=<UTC>) schema={'graphProperties': {}, 'nodes': {'ObjectNode': {}, 'SubjectNode': {}}, 'relationships': {'RELATIONSHIP': {}}} schemaWithOrientation={'graphProperties': {}, 'nodes': {'ObjectNode': {}, 'SubjectNode': {}}, 'relationships': {'RELATIONSHIP': {'direction': 'UNDIRECTED', 'properties': {}}}}>

# %% [markdown]
# As mentioned earlier the nodes are classified into SujectNodes (contains NCT Number) and ObjectNode (contains rest entites).

# %%
# Query to fetch distinct labels
def fetch_labels(tx):
    query = """
    MATCH (n) RETURN DISTINCT labels(n) AS nodeLabels
    """
    result = tx.run(query)
    return [record["nodeLabels"] for record in result]

# Main function to connect and fetch labels
def main():
    driver = GraphDatabase.driver(URI, auth=AUTH)

    try:
        with driver.session() as session:
            labels = session.read_transaction(fetch_labels)
            print("Distinct Labels in the Database:")
            for label in labels:
                print(label)
    except Exception as e:
        print(f"Error: {e}")
    finally:
        driver.close()

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-31-5d5ed6ae72de>:15: DeprecationWarning: read_transaction has been renamed to execute_read
#   labels = session.read_transaction(fetch_labels)
# Distinct Labels in the Database:
# ['SubjectNode']
# ['ObjectNode']

# %% [markdown]
# There is 1 Distinct Relationship Type

# %%
def fetch_relationship_types(tx):
    query = """
    CALL db.relationshipTypes() YIELD relationshipType
    RETURN relationshipType
    """
    result = tx.run(query)
    return [record["relationshipType"] for record in result]

# Main function to connect and fetch relationship types
def main():
    driver = GraphDatabase.driver(URI, auth=AUTH)

    try:
        with driver.session() as session:
            relationships = session.read_transaction(fetch_relationship_types)
            print("Distinct Relationship Types in the Database:")
            for relationship in relationships:
                print(relationship)
    except Exception as e:
        print(f"Error: {e}")
    finally:
        driver.close()

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-32-aead67af7762>:15: DeprecationWarning: read_transaction has been renamed to execute_read
#   relationships = session.read_transaction(fetch_relationship_types)
# Distinct Relationship Types in the Database:
# RELATIONSHIP

# %% [markdown]
# Checking connection

# %%
def main():
    try:
        driver = GraphDatabase.driver(URI, auth=AUTH)
        with driver.session() as session:
            print("Connected to Neo4j successfully!")
            # Run your queries here...
    except ServiceUnavailable as e:
        print(f"Failed to connect to Neo4j: {e}")
    finally:
        driver.close()

if __name__ == "__main__":
    main()
# Out:
# Connected to Neo4j successfully!

# %% [markdown]
# Listing all the nodes

# %%
# Function to fetch all nodes in the graph
def fetch_nodes(tx):
    query = """
    MATCH (n)
    RETURN labels(n) AS labels, n.name AS name
    """
    result = tx.run(query)
    return [{"labels": record["labels"], "name": record["name"]} for record in result]

# Main function to connect to Neo4j and retrieve nodes
def main():
    driver = GraphDatabase.driver(URI, auth=AUTH)

    try:
        with driver.session() as session:
            nodes = session.read_transaction(fetch_nodes)
            if nodes:
                print("Nodes present in the graph:")
                for node in nodes:
                    print(f"Labels: {node['labels']}, Name: {node['name']}")
            else:
                print("No nodes found in the graph.")
    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        driver.close()

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-34-4a940ca6ab8e>:16: DeprecationWarning: read_transaction has been renamed to execute_read
#   nodes = session.read_transaction(fetch_nodes)
# Streaming output truncated to the last 5000 lines.
# Labels: ['ObjectNode'], Name: Solifenacin Succinate
# Labels: ['ObjectNode'], Name: quality of life index
# Labels: ['SubjectNode'], Name: NCT00847613
# Labels: ['SubjectNode'], Name: NCT05606913
# Labels: ['ObjectNode'], Name: Percentage change in body weight
# Labels: ['SubjectNode'], Name: NCT02788513
# Labels: ['SubjectNode'], Name: NCT01396213
# Labels: ['ObjectNode'], Name: CDR-GS score
# Labels: ['SubjectNode'], Name: NCT04928313
# Labels: ['ObjectNode'], Name: CinnoRA
# Labels: ['ObjectNode'], Name: Multiple Sclerosis International Quality of Life
# Labels: ['ObjectNode'], Name: Patients diagnosed as SPMS with relapse
# Labels: ['ObjectNode'], Name: Taking other DMTs
# Labels: ['SubjectNode'], Name: NCT03277313
# Labels: ['ObjectNode'], Name: Primary Humoral Immunodeficiency
# Labels: ['ObjectNode'], Name: HYQVIA
# Labels: ['ObjectNode'], Name: Mean ASBI per participant-year
# Labels: ['ObjectNode'], Name: Mean all infections per participant-year
# Labels: ['SubjectNode'], Name: NCT04707313
# Labels: ['SubjectNode'], Name: NCT03242018
# Labels: ['SubjectNode'], Name: NCT05795218
# Labels: ['ObjectNode'], Name: directSTIM Deep Brain Stimulation System
# Labels: ['ObjectNode'], Name: Difference in percentage
# Labels: ['ObjectNode'], Name: target limb identified
# Labels: ['SubjectNode'], Name: NCT01999218
# Labels: ['ObjectNode'], Name: glycemic rescue criteria
# Labels: ['SubjectNode'], Name: NCT05018013
# Labels: ['ObjectNode'], Name: Ammoxetine Hydrochloride Enteric-coated Tablets
# Labels: ['ObjectNode'], Name: Hamilton depression scales 24
# Labels: ['SubjectNode'], Name: NCT03755518
# Labels: ['ObjectNode'], Name: red blood cells
# Labels: ['SubjectNode'], Name: NCT00857818
# Labels: ['SubjectNode'], Name: NCT03247517
# Labels: ['ObjectNode'], Name: Conners 3rd Edition
# Labels: ['SubjectNode'], Name: NCT04043234
# Labels: ['ObjectNode'], Name: RESCU System
# Labels: ['ObjectNode'], Name: prosthesis use duration
# Labels: ['ObjectNode'], Name: activity performance
# Labels: ['ObjectNode'], Name: psychosocial adjustment
# Labels: ['ObjectNode'], Name: upper limb amputation
# Labels: ['SubjectNode'], Name: NCT01526434
# Labels: ['ObjectNode'], Name: SF-36 PCS at Week 12
# Labels: ['SubjectNode'], Name: NCT05101317
# Labels: ['ObjectNode'], Name: Change in non-menstrual pelvic pain
# Labels: ['ObjectNode'], Name: Change from Baseline in the monthly mean Endometriosis Daily Impact Pain Scale
# Labels: ['ObjectNode'], Name: CFB by visit in permitted rescue medication use
# Labels: ['ObjectNode'], Name: Premenopausal Women
# Labels: ['ObjectNode'], Name: surgical diagnosis of endometriosis
# Labels: ['ObjectNode'], Name: Composite Pelvic Signs and Symptoms Score total score
# Labels: ['SubjectNode'], Name: NCT05504317
# Labels: ['SubjectNode'], Name: NCT05323617
# Labels: ['ObjectNode'], Name: Iron Deficiency Anaemia
# Labels: ['SubjectNode'], Name: NCT02000817
# Labels: ['ObjectNode'], Name: EBV Viral Load Detection
# Labels: ['SubjectNode'], Name: NCT04221217
# Labels: ['ObjectNode'], Name: fasting levels of TC ≥ 240 mg/dl
# Labels: ['ObjectNode'], Name: Serum triglycerides ≤350 mg/dL
# Labels: ['ObjectNode'], Name: aortic aneurysm
# Labels: ['ObjectNode'], Name: diabetes secondary to pancreatitis
# Labels: ['ObjectNode'], Name: anti-platelets
# Labels: ['ObjectNode'], Name: anti-coagulants
# Labels: ['ObjectNode'], Name: DOAC
# Labels: ['ObjectNode'], Name: warfarin
# Labels: ['SubjectNode'], Name: NCT05107934
# Labels: ['ObjectNode'], Name: Pericarditis recurrence
# Labels: ['ObjectNode'], Name: Percentage of days with no or minimal pain
# Labels: ['ObjectNode'], Name: Recurrent Pericarditis
# Labels: ['SubjectNode'], Name: NCT02211417
# Labels: ['ObjectNode'], Name: Oral DS107
# Labels: ['SubjectNode'], Name: NCT02207634
# Labels: ['ObjectNode'], Name: cognition and memory
# Labels: ['ObjectNode'], Name: PCSK9 Binding antiBody
# Labels: ['ObjectNode'], Name: Spatial Cognition
# Labels: ['ObjectNode'], Name: Between-errors Z Score
# Labels: ['SubjectNode'], Name: NCT04413617
# Labels: ['SubjectNode'], Name: NCT04983017
# Labels: ['ObjectNode'], Name: inflammatory age
# Labels: ['ObjectNode'], Name: Change in iAge®
# Labels: ['ObjectNode'], Name: iAge® Intervention
# Labels: ['ObjectNode'], Name: Eotaxin-1 ≥100 pg/mg
# Labels: ['ObjectNode'], Name: Growth Regulated Oncogene-alpha
# Labels: ['ObjectNode'], Name: Interferon-gamma
# Labels: ['ObjectNode'], Name: TNF-related Apoptosis Inducing Ligand
# Labels: ['ObjectNode'], Name: Mean change in heart rate
# Labels: ['ObjectNode'], Name: ankle bone density
# Labels: ['SubjectNode'], Name: NCT01401517
# Labels: ['ObjectNode'], Name: Peripheral Ischemic Ulcers
# Labels: ['ObjectNode'], Name: Sustained Release Sodium Nitrite
# Labels: ['ObjectNode'], Name: Brachial Artery FMD
# Labels: ['ObjectNode'], Name: Twice daily 40mg 80mg
# Labels: ['SubjectNode'], Name: NCT01421134
# Labels: ['ObjectNode'], Name: Flexible-Dose
# Labels: ['ObjectNode'], Name: Mean Change MADRS
# Labels: ['SubjectNode'], Name: NCT04342117
# Labels: ['ObjectNode'], Name: FL
# Labels: ['ObjectNode'], Name: PI3K-inhibitor
# Labels: ['SubjectNode'], Name: NCT04131517
# Labels: ['ObjectNode'], Name: Padsevonil
# Labels: ['ObjectNode'], Name: Ethinyl Estradiol
# Labels: ['SubjectNode'], Name: NCT03259334
# Labels: ['SubjectNode'], Name: NCT03845517
# Labels: ['ObjectNode'], Name: SRI response at Week 24
# Labels: ['SubjectNode'], Name: NCT01049217
# Labels: ['ObjectNode'], Name: HIV Neuropathy
# Labels: ['SubjectNode'], Name: NCT02316717
# Labels: ['ObjectNode'], Name: IMM-124E
# Labels: ['SubjectNode'], Name: NCT06332534
# Labels: ['ObjectNode'], Name: Endoscopic Response-50
# Labels: ['SubjectNode'], Name: NCT02341417
# Labels: ['SubjectNode'], Name: NCT02289417
# Labels: ['SubjectNode'], Name: NCT01752634
# Labels: ['SubjectNode'], Name: NCT00968617
# Labels: ['ObjectNode'], Name: Number of Participants With Composite Events of Death
# Labels: ['ObjectNode'], Name: Hemoglobin Concentration After Treatment With MK2578
# Labels: ['SubjectNode'], Name: NCT01617434
# Labels: ['SubjectNode'], Name: NCT06640517
# Labels: ['ObjectNode'], Name: Children with moderate to severe
# Labels: ['SubjectNode'], Name: NCT02132117
# Labels: ['ObjectNode'], Name: Oxymetazoline HCl Cream 1.0%
# Labels: ['SubjectNode'], Name: NCT00689117
# Labels: ['ObjectNode'], Name: CT Gel
# Labels: ['ObjectNode'], Name: Subject Global Assessment of Relief
# Labels: ['SubjectNode'], Name: NCT03218917
# Labels: ['ObjectNode'], Name: INS068
# Labels: ['ObjectNode'], Name: 4 weeks between exacerbations
# Labels: ['SubjectNode'], Name: NCT04758117
# Labels: ['ObjectNode'], Name: Juvenile Psoriatic Arthritis
# Labels: ['ObjectNode'], Name: Axial Ankylosing Spondylitis
# Labels: ['ObjectNode'], Name: Percentage of Participants with Dactylitis
# Labels: ['SubjectNode'], Name: NCT06290934
# Labels: ['ObjectNode'], Name: Any Treatment-Emergent
# Labels: ['SubjectNode'], Name: NCT03504917
# Labels: ['ObjectNode'], Name: Caregiver-reported Pediatric Quality of Life Inventory
# Labels: ['SubjectNode'], Name: NCT02585934
# Labels: ['ObjectNode'], Name: Dependence Scale Score Change
# Labels: ['SubjectNode'], Name: NCT04675034
# Labels: ['ObjectNode'], Name: ADA titre
# Labels: ['SubjectNode'], Name: NCT04732117
# Labels: ['SubjectNode'], Name: NCT00492024
# Labels: ['ObjectNode'], Name: Clinical response at TOC
# Labels: ['ObjectNode'], Name: Improvement in clinical outcomes
# Labels: ['ObjectNode'], Name: Sustained Clinical Remission
# Labels: ['ObjectNode'], Name: Day of treatment commencement to Day 42
# Labels: ['SubjectNode'], Name: NCT00616434
# Labels: ['SubjectNode'], Name: NCT06288217
# Labels: ['ObjectNode'], Name: Trigeminal Neuralgia
# Labels: ['ObjectNode'], Name: VNS Therapy
# Labels: ['ObjectNode'], Name: FMA-UE Average Change
# Labels: ['ObjectNode'], Name: Change ARAT
# Labels: ['ObjectNode'], Name: FMA-UE Response %
# Labels: ['ObjectNode'], Name: completing all pre-specified treatment sessions
# Labels: ['ObjectNode'], Name: completing all pre-specified treatment doses
# Labels: ['ObjectNode'], Name: Within 7 days of completing 6 weeks of rehabilitation
# Labels: ['SubjectNode'], Name: NCT02728934
# Labels: ['ObjectNode'], Name: Proportion of Patients With an Infusion Reaction
# Labels: ['ObjectNode'], Name: Bio-naive Patients
# Labels: ['SubjectNode'], Name: NCT06407934
# Labels: ['SubjectNode'], Name: NCT03235024
# Labels: ['SubjectNode'], Name: NCT00340834
# Labels: ['ObjectNode'], Name: Annualized ARR
# Labels: ['ObjectNode'], Name: Percentage of Participants Free From Relapse
# Labels: ['ObjectNode'], Name: One point increase from baseline
# Labels: ['SubjectNode'], Name: NCT01008696
# Labels: ['ObjectNode'], Name: Percentage of patients cured
# Labels: ['ObjectNode'], Name: Symptom Assessment Questionnaire
# Labels: ['ObjectNode'], Name: Investigator's overall assessment
# Labels: ['ObjectNode'], Name: CYP2C19 genotyping
# Labels: ['SubjectNode'], Name: NCT01712516
# Labels: ['SubjectNode'], Name: NCT03624816
# Labels: ['ObjectNode'], Name: Chin Retrusion
# Labels: ['ObjectNode'], Name: Galderma Chin Retrusion Scale
# Labels: ['SubjectNode'], Name: NCT00722917
# Labels: ['SubjectNode'], Name: NCT02544217
# Labels: ['ObjectNode'], Name: KH176
# Labels: ['ObjectNode'], Name: Oxidative Phosphorylation
# Labels: ['SubjectNode'], Name: NCT02618434
# Labels: ['ObjectNode'], Name: Impulsive Aggression
# Labels: ['SubjectNode'], Name: NCT00088634
# Labels: ['ObjectNode'], Name: New Medication
# Labels: ['SubjectNode'], Name: NCT02323334
# Labels: ['ObjectNode'], Name: Plasma Minimum A-beta 1-40
# Labels: ['SubjectNode'], Name: NCT04568434
# Labels: ['ObjectNode'], Name: Adjudicated Abdominal Clinical Event Rate
# Labels: ['ObjectNode'], Name: Proportion of Subjects Who Achieve Fasting TG Levels of < 500 mg/dL
# Labels: ['ObjectNode'], Name: History of acute or chronic pancreatitis
# Labels: ['SubjectNode'], Name: NCT04677634
# Labels: ['ObjectNode'], Name: ISOThrive Prebiotic Nectar
# Labels: ['ObjectNode'], Name: PAC-SYM score
# Labels: ['SubjectNode'], Name: NCT02966834
# Labels: ['ObjectNode'], Name: PBC-40 Scale
# Labels: ['SubjectNode'], Name: NCT00160524
# Labels: ['ObjectNode'], Name: HBI Response
# Labels: ['ObjectNode'], Name: Completed CDP870-031 or CDP870-032
# Labels: ['SubjectNode'], Name: NCT00400634
# Labels: ['ObjectNode'], Name: 12 hours off medication
# Labels: ['SubjectNode'], Name: NCT03761134
# Labels: ['ObjectNode'], Name: Chinese Patients Insulin
# Labels: ['SubjectNode'], Name: NCT00928434
# Labels: ['ObjectNode'], Name: Phase A Visit 1-8
# Labels: ['SubjectNode'], Name: NCT00446524
# Labels: ['SubjectNode'], Name: NCT03397134
# Labels: ['ObjectNode'], Name: Roluperidone
# Labels: ['SubjectNode'], Name: NCT04753034
# Labels: ['ObjectNode'], Name: TER-101 Topical Ointment
# Labels: ['SubjectNode'], Name: NCT06193434
# Labels: ['ObjectNode'], Name: Systemic clearance
# Labels: ['ObjectNode'], Name: Apparent Volume of Distribution
# Labels: ['ObjectNode'], Name: elimination half-life [t1/2z]
# Labels: ['SubjectNode'], Name: NCT02392234
# Labels: ['ObjectNode'], Name: VX-509
# Labels: ['ObjectNode'], Name: ppFEV1 at Week 48
# Labels: ['ObjectNode'], Name: second allele with CFTR mutation
# Labels: ['SubjectNode'], Name: NCT04925934
# Labels: ['ObjectNode'], Name: VIB7734
# Labels: ['SubjectNode'], Name: NCT02211534
# Labels: ['ObjectNode'], Name: Dual Field PEMF Therapy
# Labels: ['ObjectNode'], Name: Responders: Defined as subjects with a 5-point decrease in Beck Depression Inventory (BDI) score.
# Labels: ['SubjectNode'], Name: NCT05256134
# Labels: ['ObjectNode'], Name: Randomization through end of Study
# Labels: ['SubjectNode'], Name: NCT02592434
# Labels: ['ObjectNode'], Name: Disease Flare at Week 44
# Labels: ['ObjectNode'], Name: PRCSG/PRINTO criteria
# Labels: ['SubjectNode'], Name: NCT05228834
# Labels: ['ObjectNode'], Name: Voxelotor
# Labels: ['ObjectNode'], Name: Executive Functioning Composite Score
# Labels: ['ObjectNode'], Name: Pattern Comparison Processing Speed Test Scores
# Labels: ['SubjectNode'], Name: NCT00706134
# Labels: ['ObjectNode'], Name: Change From Baseline in Mean Ambulatory Pulse Pressure
# Labels: ['ObjectNode'], Name: Light Meal
# Labels: ['SubjectNode'], Name: NCT01018134
# Labels: ['SubjectNode'], Name: NCT06283524
# Labels: ['ObjectNode'], Name: eye-movement biomarkers
# Labels: ['ObjectNode'], Name: MS disease severity
# Labels: ['SubjectNode'], Name: NCT05044234
# Labels: ['ObjectNode'], Name: Cedirogant (ABBV-157)
# Labels: ['SubjectNode'], Name: NCT01422434
# Labels: ['ObjectNode'], Name: LEO 90105 Ointment
# Labels: ['ObjectNode'], Name: Target treated lesions
# Labels: ['SubjectNode'], Name: NCT04662619
# Labels: ['ObjectNode'], Name: EVI-01
# Labels: ['ObjectNode'], Name: Number of AD cases
# Labels: ['ObjectNode'], Name: Percentage of AEs
# Labels: ['SubjectNode'], Name: NCT02861118
# Labels: ['ObjectNode'], Name: reduction HBI score
# Labels: ['ObjectNode'], Name: socio-demographic characteristics
# Labels: ['SubjectNode'], Name: NCT03001219
# Labels: ['SubjectNode'], Name: NCT04817618
# Labels: ['ObjectNode'], Name: Iptacopan
# Labels: ['SubjectNode'], Name: NCT00618618
# Labels: ['SubjectNode'], Name: NCT02119819
# Labels: ['ObjectNode'], Name: Investigational New Drug
# Labels: ['SubjectNode'], Name: NCT00827918
# Labels: ['ObjectNode'], Name: Acute Schizophrenia
# Labels: ['SubjectNode'], Name: NCT00484718
# Labels: ['ObjectNode'], Name: Ultracet
# Labels: ['SubjectNode'], Name: NCT00522418
# Labels: ['ObjectNode'], Name: Baseline QOLIE Assessment
# Labels: ['SubjectNode'], Name: NCT01667419
# Labels: ['ObjectNode'], Name: Cutaneous BRAF-Mutant Melanoma
# Labels: ['SubjectNode'], Name: NCT03568318
# Labels: ['SubjectNode'], Name: NCT05323734
# Labels: ['ObjectNode'], Name: KCNT1-Related Epilepsy
# Labels: ['ObjectNode'], Name: GNX Treatment
# Labels: ['ObjectNode'], Name: ADAMS
# Labels: ['SubjectNode'], Name: NCT04968912
# Labels: ['ObjectNode'], Name: clinical assessment score
# Labels: ['SubjectNode'], Name: NCT01786512
# Labels: ['ObjectNode'], Name: Omecamtiv Mecarbil
# Labels: ['SubjectNode'], Name: NCT02242812
# Labels: ['ObjectNode'], Name: LVEDVI(H) change
# Labels: ['ObjectNode'], Name: LVMI(H) change
# Labels: ['ObjectNode'], Name: Change From Baseline in LVESVI
# Labels: ['ObjectNode'], Name: Change From Baseline in LVEDVI
# Labels: ['ObjectNode'], Name: ESS Change
# Labels: ['ObjectNode'], Name: 24-hour DBP change
# Labels: ['ObjectNode'], Name: seated SBP change
# Labels: ['ObjectNode'], Name: ABPM monitor
# Labels: ['SubjectNode'], Name: NCT00249912
# Labels: ['SubjectNode'], Name: NCT00807846
# Labels: ['ObjectNode'], Name: Parent/Caregiver's Assessment
# Labels: ['ObjectNode'], Name: Participant Quality of Life
# Labels: ['SubjectNode'], Name: NCT04776746
# Labels: ['SubjectNode'], Name: NCT01596712
# Labels: ['ObjectNode'], Name: QGE031
# Labels: ['ObjectNode'], Name: Serum QGE031 concentration
# Labels: ['ObjectNode'], Name: total IgE
# Labels: ['ObjectNode'], Name: FcεRI expression
# Labels: ['ObjectNode'], Name: Adult Japanese Participants
# Labels: ['ObjectNode'], Name: IgE serum concentrations
# Labels: ['SubjectNode'], Name: NCT01132612
# Labels: ['ObjectNode'], Name: IGA Mod 2009
# Labels: ['ObjectNode'], Name: completed the study
# Labels: ['SubjectNode'], Name: NCT03905512
# Labels: ['ObjectNode'], Name: SEL-212
# Labels: ['ObjectNode'], Name: KRYSTEXXA
# Labels: ['ObjectNode'], Name: SUA Reduction
# Labels: ['ObjectNode'], Name: Physician's Global Assessment of Disease Activity
# Labels: ['ObjectNode'], Name: Refractory to Conventional Therapy
# Labels: ['SubjectNode'], Name: NCT00777946
# Labels: ['SubjectNode'], Name: NCT03616912
# Labels: ['ObjectNode'], Name: BILAG B
# Labels: ['SubjectNode'], Name: NCT01377012
# Labels: ['SubjectNode'], Name: NCT03254446
# Labels: ['ObjectNode'], Name: TRC101
# Labels: ['ObjectNode'], Name: Changes from baseline in MAP
# Labels: ['ObjectNode'], Name: Change in JBS3 risk score
# Labels: ['ObjectNode'], Name: Stable dose of oral hypoglycemic agents
# Labels: ['SubjectNode'], Name: NCT00968812
# Labels: ['SubjectNode'], Name: NCT00243412
# Labels: ['ObjectNode'], Name: Grade III or IV AE
# Labels: ['SubjectNode'], Name: NCT02323646
# Labels: ['ObjectNode'], Name: Megestrol Acetate
# Labels: ['SubjectNode'], Name: NCT04983446
# Labels: ['ObjectNode'], Name: Coronavirus Disease 2019
# Labels: ['ObjectNode'], Name: intranasal foralumab
# Labels: ['ObjectNode'], Name: Chest X-ray Global Assessment Score
# Labels: ['ObjectNode'], Name: resolution of severe COVID-19
# Labels: ['ObjectNode'], Name: hospitalized with severe COVID-19
# Labels: ['SubjectNode'], Name: NCT01544595
# Labels: ['ObjectNode'], Name: cumulative rate PASI 75
# Labels: ['ObjectNode'], Name: PASI 50 Response
# Labels: ['SubjectNode'], Name: NCT01079195
# Labels: ['SubjectNode'], Name: NCT01167881
# Labels: ['SubjectNode'], Name: NCT00892281
# Labels: ['ObjectNode'], Name: CDAI score change
# Labels: ['SubjectNode'], Name: NCT02581995
# Labels: ['ObjectNode'], Name: NEI-VFQ-25 score
# Labels: ['SubjectNode'], Name: NCT00048581
# Labels: ['SubjectNode'], Name: NCT00082381
# Labels: ['ObjectNode'], Name: AC-3933
# Labels: ['SubjectNode'], Name: NCT01294410
# Labels: ['ObjectNode'], Name: IBDQ
# Labels: ['ObjectNode'], Name: endoscopic appearance
# Labels: ['ObjectNode'], Name: conventional therapy
# Labels: ['ObjectNode'], Name: limited to rectum
# Labels: ['ObjectNode'], Name: fulminant colitis
# Labels: ['ObjectNode'], Name: bowel perforation
# Labels: ['ObjectNode'], Name: ileostomy
# Labels: ['ObjectNode'], Name: colostomy
# Labels: ['ObjectNode'], Name: total or subtotal colectomy
# Labels: ['SubjectNode'], Name: NCT04123795
# Labels: ['SubjectNode'], Name: NCT00286481
# Labels: ['SubjectNode'], Name: NCT01280695
# Labels: ['ObjectNode'], Name: MSDC-0160
# Labels: ['ObjectNode'], Name: Change From Baseline in HOMA-IS
# Labels: ['SubjectNode'], Name: NCT00884481
# Labels: ['ObjectNode'], Name: Capacity for Work
# Labels: ['SubjectNode'], Name: NCT04153981
# Labels: ['SubjectNode'], Name: NCT01365481
# Labels: ['SubjectNode'], Name: NCT02579681
# Labels: ['ObjectNode'], Name: BG00012
# Labels: ['ObjectNode'], Name: cognitive impairment index
# Labels: ['ObjectNode'], Name: EDSS/FSS
# Labels: ['SubjectNode'], Name: NCT02516410
# Labels: ['SubjectNode'], Name: NCT01867710
# Labels: ['ObjectNode'], Name: Mineralocorticoid Excess Toxicity
# Labels: ['SubjectNode'], Name: NCT02134210
# Labels: ['SubjectNode'], Name: NCT00667810
# Labels: ['ObjectNode'], Name: Week 54
# Labels: ['SubjectNode'], Name: NCT01838681
# Labels: ['ObjectNode'], Name: Full global score remission
# Labels: ['SubjectNode'], Name: NCT03435081
# Labels: ['SubjectNode'], Name: NCT01023581
# Labels: ['SubjectNode'], Name: NCT03325010
# Labels: ['ObjectNode'], Name: TS diagnosis
# Labels: ['SubjectNode'], Name: NCT04002310
# Labels: ['ObjectNode'], Name: Number of DLEs
# Labels: ['ObjectNode'], Name: drug administration
# Labels: ['SubjectNode'], Name: NCT02878681
# Labels: ['ObjectNode'], Name: Monthly intravitreal injections
# Labels: ['SubjectNode'], Name: NCT02448381
# Labels: ['ObjectNode'], Name: SGX942
# Labels: ['ObjectNode'], Name: ≥50% CAILS improvement
# Labels: ['SubjectNode'], Name: NCT00648908
# Labels: ['SubjectNode'], Name: NCT01089023
# Labels: ['SubjectNode'], Name: NCT02586623
# Labels: ['ObjectNode'], Name: Time to intervention
# Labels: ['ObjectNode'], Name: OHSA Item #1 worsening
# Labels: ['SubjectNode'], Name: NCT03794323
# Labels: ['SubjectNode'], Name: NCT03431623
# Labels: ['ObjectNode'], Name: test drug
# Labels: ['ObjectNode'], Name: 19 years or older
# Labels: ['ObjectNode'], Name: Subjects with diabetes mellitus or chronic renal disorders
# Labels: ['SubjectNode'], Name: NCT00550550
# Labels: ['ObjectNode'], Name: Ocular Allergy Symptoms
# Labels: ['ObjectNode'], Name: Grass Sublingual Tablet
# Labels: ['SubjectNode'], Name: NCT06004050
# Labels: ['ObjectNode'], Name: HECSI-75 at Week 16
# Labels: ['ObjectNode'], Name: HECSI-90 at Week 16
# Labels: ['ObjectNode'], Name: Percentage of subjects with 3-point improvement in mean itch NRS score
# Labels: ['ObjectNode'], Name: Number of Participants Achieving EASI Reduction
# Labels: ['ObjectNode'], Name: Number of Participants With Pain Relief
# Labels: ['ObjectNode'], Name: Percentage Change in HECSI Score
# Labels: ['ObjectNode'], Name: Change in Eczema Area and Severity Index (EASI)
# Labels: ['ObjectNode'], Name: Change in HEIS Proximal Daily Activity Limitations (PDAL) Score
# Labels: ['SubjectNode'], Name: NCT01624350
# Labels: ['ObjectNode'], Name: Refractory perianal
# Labels: ['ObjectNode'], Name: Permacol™ Collagen Paste
# Labels: ['SubjectNode'], Name: NCT00789750
# Labels: ['ObjectNode'], Name: Colesevelam
# Labels: ['SubjectNode'], Name: NCT03783923
# Labels: ['ObjectNode'], Name: Limb-Girdle Muscular Dystrophy 2I
# Labels: ['ObjectNode'], Name: Deflazacort
# Labels: ['ObjectNode'], Name: Time to descend stairs
# Labels: ['ObjectNode'], Name: Time to up and go
# Labels: ['ObjectNode'], Name: Time to climb stairs
# Labels: ['ObjectNode'], Name: Time to walk 10 meters
# Labels: ['ObjectNode'], Name: Global T2 Relaxation Time
# Labels: ['SubjectNode'], Name: NCT00120523
# Labels: ['ObjectNode'], Name: Pimecrolimus Cream 1%
# Labels: ['ObjectNode'], Name: Potential Effect on the Developing Immune System
# Labels: ['ObjectNode'], Name: Atopic Eczema
# Labels: ['ObjectNode'], Name: Severity Scoring of Atopic Dermatitis Index
# Labels: ['SubjectNode'], Name: NCT01545050
# Labels: ['SubjectNode'], Name: NCT06216808
# Labels: ['ObjectNode'], Name: HyperQureTM
# Labels: ['ObjectNode'], Name: Change in ABPM
# Labels: ['ObjectNode'], Name: Change in Office SBP
# Labels: ['ObjectNode'], Name: Changes in DBP
# Labels: ['ObjectNode'], Name: Target office SBP
# Labels: ['SubjectNode'], Name: NCT03675308
# Labels: ['ObjectNode'], Name: DMARD-naïve Adults
# Labels: ['SubjectNode'], Name: NCT05274750
# Labels: ['ObjectNode'], Name: Change From Baseline in Nasal Polyp Score
# Labels: ['SubjectNode'], Name: NCT02674308
# Labels: ['ObjectNode'], Name: Baseline up to 12 months
# Labels: ['SubjectNode'], Name: NCT02407223
# Labels: ['SubjectNode'], Name: NCT00917150
# Labels: ['SubjectNode'], Name: NCT03847350
# Labels: ['ObjectNode'], Name: NEBILET
# Labels: ['SubjectNode'], Name: NCT02575950
# Labels: ['ObjectNode'], Name: Composite LSR Score
# Labels: ['SubjectNode'], Name: NCT02720523
# Labels: ['SubjectNode'], Name: NCT05265923
# Labels: ['SubjectNode'], Name: NCT05281523
# Labels: ['ObjectNode'], Name: Change From Baseline in LGS Total Score
# Labels: ['SubjectNode'], Name: NCT04239950
# Labels: ['ObjectNode'], Name: Ethyl Icosapentate
# Labels: ['ObjectNode'], Name: Lifestyle improvement
# Labels: ['SubjectNode'], Name: NCT02117050
# Labels: ['ObjectNode'], Name: Oral Dimethyl Fumarate
# Labels: ['ObjectNode'], Name: Patient Determined Disease Steps
# Labels: ['SubjectNode'], Name: NCT00573508
# Labels: ['ObjectNode'], Name: VESIcare
# Labels: ['ObjectNode'], Name: HRQL Total Score
# Labels: ['SubjectNode'], Name: NCT01362608
# Labels: ['ObjectNode'], Name: Gout Pain Intensity
# Labels: ['SubjectNode'], Name: NCT04583423
# Labels: ['SubjectNode'], Name: NCT03793023
# Labels: ['ObjectNode'], Name: Change in FBG
# Labels: ['ObjectNode'], Name: dipeptidyl peptidase-4 inhibitor
# Labels: ['SubjectNode'], Name: NCT04379050
# Labels: ['ObjectNode'], Name: Numeric Grade on Infusion Site Evaluation Scale
# Labels: ['SubjectNode'], Name: NCT02100150
# Labels: ['ObjectNode'], Name: Mild Traumatic Brain Injury
# Labels: ['ObjectNode'], Name: NNZ-2566
# Labels: ['ObjectNode'], Name: Post-Concussion Symptoms
# Labels: ['ObjectNode'], Name: Postural Stability
# Labels: ['ObjectNode'], Name: Psychological Sequelae
# Labels: ['SubjectNode'], Name: NCT01008423
# Labels: ['SubjectNode'], Name: NCT01969123
# Labels: ['ObjectNode'], Name: COWS score
# Labels: ['SubjectNode'], Name: NCT03060850
# Labels: ['ObjectNode'], Name: MCL
# Labels: ['ObjectNode'], Name: DLBCL
# Labels: ['ObjectNode'], Name: Non-Hodgkin B-Cell lymphoma
# Labels: ['SubjectNode'], Name: NCT01060150
# Labels: ['ObjectNode'], Name: Learning Skill Test (LST) Total Score
# Labels: ['SubjectNode'], Name: NCT02608450
# Labels: ['SubjectNode'], Name: NCT01985308
# Labels: ['ObjectNode'], Name: Magnetic Resonant Therapy
# Labels: ['ObjectNode'], Name: CARS score at 5 weeks
# Labels: ['ObjectNode'], Name: CARS score 36-47
# Labels: ['SubjectNode'], Name: NCT03566823
# Labels: ['SubjectNode'], Name: NCT06431750
# Labels: ['ObjectNode'], Name: Drug survival duration
# Labels: ['ObjectNode'], Name: Active joint disease
# Labels: ['ObjectNode'], Name: Absence of rash
# Labels: ['ObjectNode'], Name: Absence of splenomegaly
# Labels: ['ObjectNode'], Name: Absence of generalized lymphadenopathy
# Labels: ['ObjectNode'], Name: Normal CRP
# Labels: ['ObjectNode'], Name: Normalization of CRP
# Labels: ['ObjectNode'], Name: Absence of disease activity according to the doctor's general assessment
# Labels: ['SubjectNode'], Name: NCT00739908
# Labels: ['ObjectNode'], Name: MADRS score change
# Labels: ['ObjectNode'], Name: MADRS Remitter Rate
# Labels: ['SubjectNode'], Name: NCT01247350
# Labels: ['ObjectNode'], Name: Half life
# Labels: ['ObjectNode'], Name: Apparent Total Body Clearance
# Labels: ['SubjectNode'], Name: NCT00219050
# Labels: ['ObjectNode'], Name: History of hypertensive encephalopathy
# Labels: ['ObjectNode'], Name: Insulin-naive patients
# Labels: ['SubjectNode'], Name: NCT01618708
# Labels: ['ObjectNode'], Name: Synvisc®
# Labels: ['ObjectNode'], Name: Hylan G-F 20
# Labels: ['ObjectNode'], Name: Percentage From Baseline in WOMAC responder
# Labels: ['ObjectNode'], Name: Symptomatic knee OA
# Labels: ['ObjectNode'], Name: Primary Osteoarthritis of the Hip
# Labels: ['SubjectNode'], Name: NCT04170023
# Labels: ['ObjectNode'], Name: Percentage of Participants With Transfusion Avoidance
# Labels: ['SubjectNode'], Name: NCT04292223
# Labels: ['ObjectNode'], Name: MSFC score
# Labels: ['SubjectNode'], Name: NCT03529123
# Labels: ['SubjectNode'], Name: NCT00660023
# Labels: ['SubjectNode'], Name: NCT00308750
# Labels: ['ObjectNode'], Name: RECIST v1.1
# Labels: ['SubjectNode'], Name: NCT02013050
# Labels: ['ObjectNode'], Name: SGX301
# Labels: ['ObjectNode'], Name: Duration of SOM
# Labels: ['ObjectNode'], Name: Residual SOM
# Labels: ['ObjectNode'], Name: Incidence clinically significant findings
# Labels: ['ObjectNode'], Name: WHO OM grading scale
# Labels: ['SubjectNode'], Name: NCT02568423
# Labels: ['ObjectNode'], Name: first generation Japanese or Caucasian
# Labels: ['ObjectNode'], Name: disseminated herpes zoster
# Labels: ['ObjectNode'], Name: latent tuberculosis (TB) prophylaxis
# Labels: ['SubjectNode'], Name: NCT06101823
# Labels: ['ObjectNode'], Name: OpSCF
# Labels: ['ObjectNode'], Name: Proportion of subjects achieving at least a 2-grade reduction from baseline to clear (0) or almost clear (1) in vIGA-AD
# Labels: ['ObjectNode'], Name: probable AD diagnosis
# Labels: ['ObjectNode'], Name: at least a 6-month history of AD
# Labels: ['ObjectNode'], Name: no significant medical history
# Labels: ['ObjectNode'], Name: not used tralokinumab within 12 weeks prior to Day 1
# Labels: ['ObjectNode'], Name: not used dupilumab within 26 weeks prior to Day 1
# Labels: ['SubjectNode'], Name: NCT01922050
# Labels: ['SubjectNode'], Name: NCT02390050
# Labels: ['ObjectNode'], Name: Yogliptin Tablets
# Labels: ['SubjectNode'], Name: NCT05549323
# Labels: ['ObjectNode'], Name: endoscopic and histologic evidence
# Labels: ['ObjectNode'], Name: no individual subscore \>1
# Labels: ['SubjectNode'], Name: NCT03924323
# Labels: ['ObjectNode'], Name: PARS severity score
# Labels: ['ObjectNode'], Name: CGI-C change
# Labels: ['ObjectNode'], Name: Change CGAS
# Labels: ['SubjectNode'], Name: NCT05130450
# Labels: ['SubjectNode'], Name: NCT00601250
# Labels: ['ObjectNode'], Name: BI 1356
# Labels: ['SubjectNode'], Name: NCT05272150
# Labels: ['SubjectNode'], Name: NCT00325195
# Labels: ['ObjectNode'], Name: PEG-uricase
# Labels: ['ObjectNode'], Name: Plasma Uric Acid Responder
# Labels: ['ObjectNode'], Name: Tophus Burden
# Labels: ['ObjectNode'], Name: Serum Urate < 6.0 mg/dL
# Labels: ['SubjectNode'], Name: NCT03055195
# Labels: ['SubjectNode'], Name: NCT04087395
# Labels: ['ObjectNode'], Name: RHA® 4 With New Anesthetic Agent
# Labels: ['ObjectNode'], Name: RHA® 4-Lidocaine
# Labels: ['ObjectNode'], Name: Injection pain
# Labels: ['ObjectNode'], Name: Participant's Assessment of Treatment Effects
# Labels: ['SubjectNode'], Name: NCT03328195
# Labels: ['ObjectNode'], Name: Severe Impairment Battery Total Score
# Labels: ['SubjectNode'], Name: NCT00517881
# Labels: ['ObjectNode'], Name: Subcutaneous C.E.R.A.
# Labels: ['ObjectNode'], Name: pre-dialytic
# Labels: ['SubjectNode'], Name: NCT01208181
# Labels: ['SubjectNode'], Name: NCT03324581
# Labels: ['ObjectNode'], Name: CAARS Total ADHD Symptoms Score
# Labels: ['ObjectNode'], Name: ADHD-RS-5 Inattention Subscale
# Labels: ['ObjectNode'], Name: willing to discontinue prohibited psychotropic medication
# Labels: ['ObjectNode'], Name: no history of inadequate response to atomoxetine
# Labels: ['ObjectNode'], Name: no allergies to stimulant or nonstimulant ADHD medications
# Labels: ['ObjectNode'], Name: no lifetime history of bipolar disorder
# Labels: ['ObjectNode'], Name: No major psychiatric disorders
# Labels: ['ObjectNode'], Name: no panic disorder
# Labels: ['SubjectNode'], Name: NCT03260595
# Labels: ['ObjectNode'], Name: Crisaborole Ointment 2%
# Labels: ['ObjectNode'], Name: Superficial Irritation Scores
# Labels: ['SubjectNode'], Name: NCT02349295
# Labels: ['SubjectNode'], Name: NCT01416181
# Labels: ['SubjectNode'], Name: NCT02769481
# Labels: ['SubjectNode'], Name: NCT00087581
# Labels: ['ObjectNode'], Name: Single organ recipient
# Labels: ['ObjectNode'], Name: MMF immunosuppression
# Labels: ['ObjectNode'], Name: History of malignancy
# Labels: ['SubjectNode'], Name: NCT02799381
# Labels: ['ObjectNode'], Name: Parkinson's disease Questionnaire-8
# Labels: ['SubjectNode'], Name: NCT00846781
# Labels: ['ObjectNode'], Name: Denufosol Tetrasodium Inhalation Solution
# Labels: ['ObjectNode'], Name: Completed Study C-1801
# Labels: ['ObjectNode'], Name: female of childbearing potential
# Labels: ['ObjectNode'], Name: condition that might affect compliance with study procedures
# Labels: ['SubjectNode'], Name: NCT01816295
# Labels: ['ObjectNode'], Name: Change in testosterone
# Labels: ['ObjectNode'], Name: Testosterone Solution
# Labels: ['ObjectNode'], Name: Change in SAID Scale
# Labels: ['ObjectNode'], Name: Hypogonadotropic Hypogonadism
# Labels: ['SubjectNode'], Name: NCT05908695
# Labels: ['ObjectNode'], Name: Sodium Oligo-mannurarate Capsule
# Labels: ['ObjectNode'], Name: Progressive memory decline
# Labels: ['ObjectNode'], Name: modified Hachinski Ischaemia score > 4
# Labels: ['SubjectNode'], Name: NCT04997395
# Labels: ['ObjectNode'], Name: medicinal cannabis
# Labels: ['ObjectNode'], Name: global health score
# Labels: ['SubjectNode'], Name: NCT00082095
# Labels: ['ObjectNode'], Name: Doxorubicin
# Labels: ['ObjectNode'], Name: Gemcitabine
# Labels: ['ObjectNode'], Name: Subjective Significance Questionnaire
# Labels: ['SubjectNode'], Name: NCT04455581
# Labels: ['ObjectNode'], Name: Percent Change From Baseline to Week 24 in Non-HDL-C
# Labels: ['ObjectNode'], Name: Apolipoprotein (Apo) B at Week 24
# Labels: ['ObjectNode'], Name: Lipo(a) at Week 12
# Labels: ['SubjectNode'], Name: NCT06427395
# Labels: ['ObjectNode'], Name: Saroglitazar Magnesium
# Labels: ['ObjectNode'], Name: Model for End Stage Liver Disease 3.0 score
# Labels: ['ObjectNode'], Name: known Gilbert's syndrome
# Labels: ['SubjectNode'], Name: NCT01655381
# Labels: ['SubjectNode'], Name: NCT06167681
# Labels: ['ObjectNode'], Name: NouvNeu001
# Labels: ['ObjectNode'], Name: Waking Hours in "off" State
# Labels: ['ObjectNode'], Name: standard dose of oral L-dopa
# Labels: ['SubjectNode'], Name: NCT06023095
# Labels: ['SubjectNode'], Name: NCT01499095
# Labels: ['SubjectNode'], Name: NCT03269695
# Labels: ['ObjectNode'], Name: Not in Remission
# Labels: ['SubjectNode'], Name: NCT04998981
# Labels: ['ObjectNode'], Name: MK-8777
# Labels: ['ObjectNode'], Name: Ability to complete study
# Labels: ['SubjectNode'], Name: NCT04485481
# Labels: ['ObjectNode'], Name: Area under the plasma concentration curve
# Labels: ['ObjectNode'], Name: QT-interval measurements corrected according to the Fridericia rule (QTcF \>450 msec) during controlled rest at Screening or family history of long QT syndrome
# Labels: ['SubjectNode'], Name: NCT00848081
# Labels: ['ObjectNode'], Name: treatment-emergent dizziness
# Labels: ['ObjectNode'], Name: Orthostatic Vital Signs Test
# Labels: ['ObjectNode'], Name: Postvoid Residual Volume
# Labels: ['SubjectNode'], Name: NCT02293681
# Labels: ['ObjectNode'], Name: Hip Disability
# Labels: ['ObjectNode'], Name: Harris Hip Score
# Labels: ['SubjectNode'], Name: NCT01561781
# Labels: ['ObjectNode'], Name: AUC Digoxin
# Labels: ['ObjectNode'], Name: No current smoking
# Labels: ['SubjectNode'], Name: NCT01310114
# Labels: ['SubjectNode'], Name: NCT05523895
# Labels: ['ObjectNode'], Name: CGI-I of irritability
# Labels: ['ObjectNode'], Name: CGI-S of Irritability
# Labels: ['ObjectNode'], Name: RBANS Total Score
# Labels: ['ObjectNode'], Name: VABS-Socialization score
# Labels: ['SubjectNode'], Name: NCT01468181
# Labels: ['SubjectNode'], Name: NCT03290781
# Labels: ['ObjectNode'], Name: Induction Baseline
# Labels: ['SubjectNode'], Name: NCT04340895
# Labels: ['ObjectNode'], Name: Therapy Timely Adjustment Based on Self-monitoring
# Labels: ['ObjectNode'], Name: Self-monitoring
# Labels: ['SubjectNode'], Name: NCT01473381
# Labels: ['SubjectNode'], Name: NCT03717012
# Labels: ['ObjectNode'], Name: Pulmonary Rehabilitation
# Labels: ['SubjectNode'], Name: NCT04513912
# Labels: ['ObjectNode'], Name: Complete Response at Week 56
# Labels: ['SubjectNode'], Name: NCT05148312
# Labels: ['ObjectNode'], Name: AQ001S
# Labels: ['ObjectNode'], Name: blood Tmax
# Labels: ['ObjectNode'], Name: blood Cmax
# Labels: ['ObjectNode'], Name: blood AUC
# Labels: ['SubjectNode'], Name: NCT05111912
# Labels: ['SubjectNode'], Name: NCT00628212
# Labels: ['ObjectNode'], Name: Adult patients age≥18 years
# Labels: ['ObjectNode'], Name: No prohibited drug use within 12 weeks
# Labels: ['SubjectNode'], Name: NCT04932512
# Labels: ['ObjectNode'], Name: Percentage of Participants With 75% Reduction From Baseline in PASI
# Labels: ['ObjectNode'], Name: Absolute change in ALT
# Labels: ['ObjectNode'], Name: at least 1-point Improvement in Hepatocellular Ballooning or Lobular Inflammation
# Labels: ['SubjectNode'], Name: NCT02311881
# Labels: ['ObjectNode'], Name: Mean relative change
# Labels: ['SubjectNode'], Name: NCT03611010
# Labels: ['ObjectNode'], Name: Day 15 HDL-C
# Labels: ['ObjectNode'], Name: Day 15 LDL-C
# Labels: ['ObjectNode'], Name: steady-state
# Labels: ['SubjectNode'], Name: NCT06651281
# Labels: ['ObjectNode'], Name: SES-CD
# Labels: ['SubjectNode'], Name: NCT03835481
# Labels: ['SubjectNode'], Name: NCT01850381
# Labels: ['ObjectNode'], Name: GM 608
# Labels: ['SubjectNode'], Name: NCT01832610
# Labels: ['ObjectNode'], Name: Readmission to ED
# Labels: ['ObjectNode'], Name: Health Status Change
# Labels: ['ObjectNode'], Name: Intermacs definition
# Labels: ['SubjectNode'], Name: NCT05256810
# Labels: ['ObjectNode'], Name: Percent Change sUA
# Labels: ['ObjectNode'], Name: Plasma Concentrations of ALN-XDH
# Labels: ['ObjectNode'], Name: High Serum Uric Acid Level
# Labels: ['SubjectNode'], Name: NCT01018810
# Labels: ['ObjectNode'], Name: Study BDAD
# Labels: ['ObjectNode'], Name: 8 patients
# Labels: ['SubjectNode'], Name: NCT02998710
# Labels: ['ObjectNode'], Name: Homocystinuria
# Labels: ['ObjectNode'], Name: Met cycle metabolites levels
# Labels: ['SubjectNode'], Name: NCT05208281
# Labels: ['ObjectNode'], Name: GNR-086
# Labels: ['ObjectNode'], Name: uGAG Excretion
# Labels: ['ObjectNode'], Name: Serum GAG level
# Labels: ['ObjectNode'], Name: Large joint range of motion
# Labels: ['ObjectNode'], Name: Trough Forced Expiratory Volume
# Labels: ['SubjectNode'], Name: NCT00998881
# Labels: ['ObjectNode'], Name: No acarbose/metformin 3 months prior
# Labels: ['SubjectNode'], Name: NCT01662310
# Labels: ['SubjectNode'], Name: NCT00659581
# Labels: ['SubjectNode'], Name: NCT03325881
# Labels: ['SubjectNode'], Name: NCT03338010
# Labels: ['SubjectNode'], Name: NCT00153010
# Labels: ['ObjectNode'], Name: NS-229
# Labels: ['ObjectNode'], Name: Modified Alzheimer's Disease Cooperative Study-Clinical Global Impression of Change
# Labels: ['ObjectNode'], Name: Changes vital signs
# Labels: ['ObjectNode'], Name: population PK parameters
# Labels: ['ObjectNode'], Name: Modified Hachinski Ischemia Scale score of less than or equal to 4
# Labels: ['ObjectNode'], Name: central nervous system imaging compatible with Dementia of the Alzheimer's Type
# Labels: ['SubjectNode'], Name: NCT03325712
# Labels: ['SubjectNode'], Name: NCT02493712
# Labels: ['ObjectNode'], Name: IBD98-M
# Labels: ['SubjectNode'], Name: NCT01426412
# Labels: ['ObjectNode'], Name: Number Participants With Detectable Levels
# Labels: ['ObjectNode'], Name: Japanese descent; statin naive; LDL-C 100-180 mg/dL
# Labels: ['SubjectNode'], Name: NCT06259981
# Labels: ['ObjectNode'], Name: GLY-200
# Labels: ['ObjectNode'], Name: no weight loss/gain medication in last 6 months
# Labels: ['ObjectNode'], Name: no weight change >5% in last 3 months
# Labels: ['ObjectNode'], Name: no gastrointestinal motility affecting drug
# Labels: ['ObjectNode'], Name: no gastric pH affecting drug
# Labels: ['ObjectNode'], Name: no nausea
# Labels: ['SubjectNode'], Name: NCT01037881
# Labels: ['ObjectNode'], Name: LEO 19123 Cream
# Labels: ['ObjectNode'], Name: Symptom Free Responders
# Labels: ['ObjectNode'], Name: Symptom free responders
# Labels: ['SubjectNode'], Name: NCT05027581
# Labels: ['ObjectNode'], Name: Chondrochymal®
# Labels: ['ObjectNode'], Name: target knee
# Labels: ['SubjectNode'], Name: NCT01355081
# Labels: ['SubjectNode'], Name: NCT00410410
# Labels: ['SubjectNode'], Name: NCT05528510
# Labels: ['ObjectNode'], Name: inadequate response to immunomodulators
# Labels: ['SubjectNode'], Name: NCT01120210
# Labels: ['ObjectNode'], Name: Least Squares mean change
# Labels: ['ObjectNode'], Name: Baseline up through 3 hours
# Labels: ['SubjectNode'], Name: NCT03287310
# Labels: ['ObjectNode'], Name: Change from baseline in neutrophil elastase levels
# Labels: ['ObjectNode'], Name: Moderate to Severe Asthma
# Labels: ['SubjectNode'], Name: NCT06499012
# Labels: ['ObjectNode'], Name: Sarcopenia
# Labels: ['ObjectNode'], Name: Nutrilite All-plant Protein Booster
# Labels: ['ObjectNode'], Name: Improvement of Fat and Muscle Portions
# Labels: ['ObjectNode'], Name: Middle-aged and Elderly People
# Labels: ['SubjectNode'], Name: NCT03815812
# Labels: ['ObjectNode'], Name: Lp(a) change
# Labels: ['SubjectNode'], Name: NCT04876781
# Labels: ['ObjectNode'], Name: Xeljanz XR
# Labels: ['SubjectNode'], Name: NCT01753310
# Labels: ['SubjectNode'], Name: NCT02547714
# Labels: ['SubjectNode'], Name: NCT01857895
# Labels: ['ObjectNode'], Name: Nausea Severity Score
# Labels: ['SubjectNode'], Name: NCT02041195
# Labels: ['SubjectNode'], Name: NCT02717195
# Labels: ['ObjectNode'], Name: Lu AF11167
# Labels: ['SubjectNode'], Name: NCT01617681
# Labels: ['SubjectNode'], Name: NCT02435914
# Labels: ['ObjectNode'], Name: Topical Ophthalmic AGN-195263
# Labels: ['ObjectNode'], Name: Change in conjunctival and corneal staining
# Labels: ['SubjectNode'], Name: NCT03345914
# Labels: ['SubjectNode'], Name: NCT04760314
# Labels: ['SubjectNode'], Name: NCT01116895
# Labels: ['SubjectNode'], Name: NCT02893995
# Labels: ['ObjectNode'], Name: Subject Discontinuations
# Labels: ['SubjectNode'], Name: NCT03047395
# Labels: ['SubjectNode'], Name: NCT02106195
# Labels: ['SubjectNode'], Name: NCT03762681
# Labels: ['SubjectNode'], Name: NCT00874614
# Labels: ['ObjectNode'], Name: Malignant Relapsed/Refractory Pheochromocytoma/Paraganglioma
# Labels: ['ObjectNode'], Name: Ultratrace Iobenguane I131
# Labels: ['ObjectNode'], Name: Therapeutic Dose of AZEDRA®
# Labels: ['SubjectNode'], Name: NCT02001181
# Labels: ['ObjectNode'], Name: Whole body surface area affected
# Labels: ['SubjectNode'], Name: NCT02279095
# Labels: ['ObjectNode'], Name: Palovarotene
# Labels: ['ObjectNode'], Name: Percentage of Participants Who do Not Experience a Flare
# Labels: ['ObjectNode'], Name: Annualized change in HO volume
# Labels: ['SubjectNode'], Name: NCT00303381
# Labels: ['SubjectNode'], Name: NCT01064414
# Labels: ['ObjectNode'], Name: T2DM and HF
# Labels: ['ObjectNode'], Name: pancreas or beta cell transplantation
# Labels: ['ObjectNode'], Name: kidney disease requiring immunosuppressive therapy
# Labels: ['ObjectNode'], Name: history of dialysis or kidney transplant
# Labels: ['ObjectNode'], Name: renal illness
# Labels: ['ObjectNode'], Name: history of a severe hypoglycemic episode
# Labels: ['SubjectNode'], Name: NCT00092014
# Labels: ['ObjectNode'], Name: Alendronate
# Labels: ['ObjectNode'], Name: Bilateral hip replacements
# Labels: ['ObjectNode'], Name: Metabolic bone disease
# Labels: ['ObjectNode'], Name: Medications affecting bone turnover
# Labels: ['SubjectNode'], Name: NCT02068495
# Labels: ['SubjectNode'], Name: NCT02428595
# Labels: ['ObjectNode'], Name: Eclipse System
# Labels: ['ObjectNode'], Name: Number of Participants With Response to Treatment
# Labels: ['ObjectNode'], Name: St. Mark's Incontinence Severity Score
# Labels: ['ObjectNode'], Name: Fecal Incontinence Quality of Life (FIQoL) Score
# Labels: ['ObjectNode'], Name: Intent to Treat (ITT) Cohort
# Labels: ['ObjectNode'], Name: Per Protocol (PP) Population
# Labels: ['SubjectNode'], Name: NCT00747214
# Labels: ['SubjectNode'], Name: NCT01533714
# Labels: ['SubjectNode'], Name: NCT03440814
# Labels: ['ObjectNode'], Name: Choline Alphoscerate
# Labels: ['ObjectNode'], Name: HQ-CT Change
# Labels: ['ObjectNode'], Name: GI-C
# Labels: ['ObjectNode'], Name: PWS condition
# Labels: ['SubjectNode'], Name: NCT01618695
# Labels: ['SubjectNode'], Name: NCT04288895
# Labels: ['SubjectNode'], Name: NCT02185014
# Labels: ['ObjectNode'], Name: Successfully completed M14-115
# Labels: ['ObjectNode'], Name: Week 12 ileocolonoscopy
# Labels: ['ObjectNode'], Name: prior and concomitant medication requirements
# Labels: ['ObjectNode'], Name: evidence of active or latent tuberculosis
# Labels: ['SubjectNode'], Name: NCT05669014
# Labels: ['ObjectNode'], Name: TIS ≥ 20
# Labels: ['ObjectNode'], Name: 2 consecutive study visits
# Labels: ['SubjectNode'], Name: NCT01809314
# Labels: ['ObjectNode'], Name: Receiving chemotherapy
# Labels: ['SubjectNode'], Name: NCT01896895
# Labels: ['ObjectNode'], Name: JRS Severity Subscore
# Labels: ['SubjectNode'], Name: NCT05327595
# Labels: ['SubjectNode'], Name: NCT01772095
# Labels: ['ObjectNode'], Name: Reliable caregivers
# Labels: ['SubjectNode'], Name: NCT03562195
# Labels: ['SubjectNode'], Name: NCT02315755
# Labels: ['ObjectNode'], Name: mRCC
# Labels: ['ObjectNode'], Name: Targeted Treatments
# Labels: ['ObjectNode'], Name: FKSI-15 Score
# Labels: ['ObjectNode'], Name: disease treatment
# Labels: ['SubjectNode'], Name: NCT06328712
# Labels: ['ObjectNode'], Name: Charcot-Marie-Tooth 4J
# Labels: ['ObjectNode'], Name: ENT-01
# Labels: ['ObjectNode'], Name: CMT examination score change
# Labels: ['ObjectNode'], Name: Rasch-modified CMTES score change
# Labels: ['ObjectNode'], Name: Rasch-modified CMTNSv2 score change
# Labels: ['ObjectNode'], Name: ONLS score change
# Labels: ['SubjectNode'], Name: NCT01474512
# Labels: ['SubjectNode'], Name: NCT01551446
# Labels: ['ObjectNode'], Name: Change in cerebral perfusion
# Labels: ['ObjectNode'], Name: Haemodynamics Parameters
# Labels: ['ObjectNode'], Name: Plasma concentration of bardoxolone methyl
# Labels: ['ObjectNode'], Name: Change in cerebral white matter microstructure
# Labels: ['ObjectNode'], Name: Change in total body water
# Labels: ['SubjectNode'], Name: NCT02620046
# Labels: ['ObjectNode'], Name: Duration of Exposure
# Labels: ['ObjectNode'], Name: Participant's Exposure
# Labels: ['SubjectNode'], Name: NCT03635112
# Labels: ['SubjectNode'], Name: NCT01100112
# Labels: ['ObjectNode'], Name: Oral Viscous Budesonide
# Labels: ['SubjectNode'], Name: NCT06462612
# Labels: ['SubjectNode'], Name: NCT06217146
# Labels: ['ObjectNode'], Name: Medical Cannabis Aerosol
# Labels: ['ObjectNode'], Name: Change in agitation
# Labels: ['ObjectNode'], Name: Neuropsychiatric Inventory Agitation/Aggression Domain Score
# Labels: ['ObjectNode'], Name: legal guardian
# Labels: ['ObjectNode'], Name: stable SoC for treatment of agitation
# Labels: ['SubjectNode'], Name: NCT05173012
# Labels: ['ObjectNode'], Name: Diagnosis of ET
# Labels: ['SubjectNode'], Name: NCT02017912
# Labels: ['ObjectNode'], Name: Autologous MSC-NTF Cells
# Labels: ['ObjectNode'], Name: Change From Baseline in ALSFRS-R at 12 Months
# Labels: ['ObjectNode'], Name: Change in SVC Slopes
# Labels: ['SubjectNode'], Name: NCT01631812
# Labels: ['ObjectNode'], Name: Absolute OFF Time
# Labels: ['SubjectNode'], Name: NCT02076412
# Labels: ['ObjectNode'], Name: Bleeding According to IBLS
# Labels: ['SubjectNode'], Name: NCT04607512
# Labels: ['ObjectNode'], Name: ΔPR
# Labels: ['ObjectNode'], Name: ΔHR
# Labels: ['ObjectNode'], Name: therapeutic dose
# Labels: ['SubjectNode'], Name: NCT06324812
# Labels: ['ObjectNode'], Name: Pediatric Chinese Patients
# Labels: ['SubjectNode'], Name: NCT00395512
# Labels: ['SubjectNode'], Name: NCT03626012
# Labels: ['ObjectNode'], Name: C9ORF72 amyotrophic lateral sclerosis (ALS)/frontotemporal dementia (FTD)
# Labels: ['SubjectNode'], Name: NCT01614912
# Labels: ['ObjectNode'], Name: Week 6 assessment
# Labels: ['SubjectNode'], Name: NCT02640612
# Labels: ['SubjectNode'], Name: NCT01808612
# Labels: ['ObjectNode'], Name: Anxiety/Somatization subscale
# Labels: ['ObjectNode'], Name: Retardation/Somatization subscale
# Labels: ['SubjectNode'], Name: NCT03143712
# Labels: ['ObjectNode'], Name: last quantifiable concentration
# Labels: ['ObjectNode'], Name: Males and females 18 to 50 years of age
# Labels: ['SubjectNode'], Name: NCT06198712
# Labels: ['ObjectNode'], Name: Etavopivat
# Labels: ['ObjectNode'], Name: Percentage Who Prematurely Discontinued
# Labels: ['ObjectNode'], Name: Number of dose interruptions
# Labels: ['ObjectNode'], Name: Number of dose reductions
# Labels: ['ObjectNode'], Name: Change from baseline in Annualized Rate of VOC
# Labels: ['ObjectNode'], Name: Change from baseline in VOCs
# Labels: ['SubjectNode'], Name: NCT01166646
# Labels: ['ObjectNode'], Name: Topical Investigational Lotion
# Labels: ['ObjectNode'], Name: Approved Cream
# Labels: ['ObjectNode'], Name: Disease Severity Success
# Labels: ['ObjectNode'], Name: Number of Subjects Whose Signs of Psoriasis Was Designated "Success
# Labels: ['SubjectNode'], Name: NCT01313312
# Labels: ['ObjectNode'], Name: MCHC
# Labels: ['ObjectNode'], Name: Treatment cycle
# Labels: ['SubjectNode'], Name: NCT02955212
# Labels: ['SubjectNode'], Name: NCT00785512
# Labels: ['ObjectNode'], Name: nebivolol
# Labels: ['SubjectNode'], Name: NCT04857112
# Labels: ['SubjectNode'], Name: NCT06057012
# Labels: ['ObjectNode'], Name: BRII-296
# Labels: ['ObjectNode'], Name: Glasgow Coma Scale Score
# Labels: ['SubjectNode'], Name: NCT06625346
# Labels: ['ObjectNode'], Name: Valsartan and Amlodipine
# Labels: ['SubjectNode'], Name: NCT03943446
# Labels: ['SubjectNode'], Name: NCT01227512
# Labels: ['ObjectNode'], Name: Fluid Restriction
# Labels: ['ObjectNode'], Name: Change From Baseline to 24 and 72 Hours Post Dose in CGI-S of Hyponatremia Symptoms.
# Labels: ['ObjectNode'], Name: Change From Baseline to 48 Hour Post Dose in Clinical Global Impression-Severity (CGI-S) of Hyponatremia Symptoms.
# Labels: ['SubjectNode'], Name: NCT02670746
# Labels: ['ObjectNode'], Name: Nab-paclitaxel
# Labels: ['ObjectNode'], Name: Capecitabine
# Labels: ['ObjectNode'], Name: Grade 1-5 neuropathy
# Labels: ['SubjectNode'], Name: NCT01728246
# Labels: ['ObjectNode'], Name: ODI Score
# Labels: ['SubjectNode'], Name: NCT03258814
# Labels: ['ObjectNode'], Name: Combined Adalimumab Treatment
# Labels: ['ObjectNode'], Name: Active Supervised Training
# Labels: ['ObjectNode'], Name: Change Form Baseline
# Labels: ['ObjectNode'], Name: Patients With AS
# Labels: ['SubjectNode'], Name: NCT01472614
# Labels: ['ObjectNode'], Name: HbA1c reduction ≥0.5%
# Labels: ['ObjectNode'], Name: Reduction in AUCglucose
# Labels: ['ObjectNode'], Name: Reduction of venous 2h-PG
# Labels: ['ObjectNode'], Name: Change From Baseline in High Molecular Weight Adiponectin
# Labels: ['ObjectNode'], Name: Quantitative liver function
# Labels: ['ObjectNode'], Name: n... [TRUNCATED]
# Labels: ['SubjectNode'], Name: NCT01493414
# Labels: ['ObjectNode'], Name: INC424
# Labels: ['ObjectNode'], Name: ≥35% spleen volume reduction
# Labels: ['ObjectNode'], Name: Best Overall Response
# Labels: ['ObjectNode'], Name: Spleen length >10 cm
# ...
# Labels: ['ObjectNode'], Name: Change from Baseline CGI-S Score
# Labels: ['SubjectNode'], Name: NCT00772577
# Labels: ['SubjectNode'], Name: NCT05026177
# Labels: ['ObjectNode'], Name: Simufilam
# Labels: ['SubjectNode'], Name: NCT04762277
# Labels: ['ObjectNode'], Name: TNFi-naïve
# Labels: ['ObjectNode'], Name: TNFi-failure population
# Labels: ['SubjectNode'], Name: NCT04916977
# Labels: ['ObjectNode'], Name: Comprehensive burden
# Labels: ['ObjectNode'], Name: median Mainz Severity Score Index
# Labels: ['SubjectNode'], Name: NCT00406653
# Labels: ['ObjectNode'], Name: Clinical Response by DAIBD
# Labels: ['SubjectNode'], Name: NCT03394677
# Labels: ['ObjectNode'], Name: RVT-501 Topical Ointment
# Labels: ['ObjectNode'], Name: Body Surface Area Efficacy
# Labels: ['SubjectNode'], Name: NCT02898753
# Labels: ['ObjectNode'], Name: Late-Onset Pompe Disease
# Labels: ['ObjectNode'], Name: VAL-1221
# Labels: ['ObjectNode'], Name: Anti-VAL-1221 Antibodies
# Labels: ['ObjectNode'], Name: GAA Antibodies
# Labels: ['SubjectNode'], Name: NCT04187547
# Labels: ['ObjectNode'], Name: RUD-Lite
# Labels: ['SubjectNode'], Name: NCT01468077
# Labels: ['ObjectNode'], Name: Change in lipid variables
# Labels: ['ObjectNode'], Name: Completed Visit 7
# Labels: ['SubjectNode'], Name: NCT04221477
# Labels: ['ObjectNode'], Name: Death or Renal-related Events
# Labels: ['ObjectNode'], Name: active proliferative LN
# Labels: ['SubjectNode'], Name: NCT06603077
# Labels: ['ObjectNode'], Name: AVTX-803
# Labels: ['ObjectNode'], Name: inflammatory nodule/abscess count
# Labels: ['SubjectNode'], Name: NCT03563053
# Labels: ['ObjectNode'], Name: EryDex System
# Labels: ['SubjectNode'], Name: NCT04044547
# Labels: ['SubjectNode'], Name: NCT00078377
# Labels: ['ObjectNode'], Name: ICSD criteria
# Labels: ['SubjectNode'], Name: NCT00737477
# Labels: ['ObjectNode'], Name: Time spent in target range
# Labels: ['SubjectNode'], Name: NCT05431153
# Labels: ['SubjectNode'], Name: NCT01041677
# Labels: ['ObjectNode'], Name: R935788
# Labels: ['ObjectNode'], Name: History of Obesity
# Labels: ['ObjectNode'], Name: Weight reducing diet
# Labels: ['ObjectNode'], Name: former smokers
# Labels: ['SubjectNode'], Name: NCT02129777
# Labels: ['SubjectNode'], Name: NCT06083753
# Labels: ['ObjectNode'], Name: PIPE-307
# Labels: ['ObjectNode'], Name: monocular 2.5% LCLA
# Labels: ['ObjectNode'], Name: binocular 2.5% LCLA
# Labels: ['ObjectNode'], Name: MRI Scale
# Labels: ['ObjectNode'], Name: blood concentration levels
# Labels: ['SubjectNode'], Name: NCT01553747
# Labels: ['SubjectNode'], Name: NCT01305577
# Labels: ['SubjectNode'], Name: NCT03562377
# Labels: ['ObjectNode'], Name: Anti-meningococcal IgG
# Labels: ['SubjectNode'], Name: NCT01469377
# Labels: ['SubjectNode'], Name: NCT00502853
# Labels: ['ObjectNode'], Name: Bone Edema Score
# Labels: ['SubjectNode'], Name: NCT00394953
# Labels: ['SubjectNode'], Name: NCT05428345
# Labels: ['SubjectNode'], Name: NCT03412747
# Labels: ['SubjectNode'], Name: NCT04921345
# Labels: ['SubjectNode'], Name: NCT06490445
# Labels: ['ObjectNode'], Name: Medical Cannabis Oil
# Labels: ['SubjectNode'], Name: NCT01194245
# Labels: ['ObjectNode'], Name: 7-Point Self Monitored Plasma Glucose
# Labels: ['SubjectNode'], Name: NCT06647745
# Labels: ['ObjectNode'], Name: THP-00102
# Labels: ['ObjectNode'], Name: Change rate of MSSBP
# Labels: ['SubjectNode'], Name: NCT03470545
# Labels: ['ObjectNode'], Name: Noonan Syndrome Hypertrophic Cardiomyopathy
# Labels: ['ObjectNode'], Name: Mavacamten
# Labels: ['ObjectNode'], Name: peak oxygen consumption
# Labels: ['SubjectNode'], Name: NCT00095147
# Labels: ['ObjectNode'], Name: immunosuppressants
# Labels: ['SubjectNode'], Name: NCT03785145
# Labels: ['ObjectNode'], Name: Lateral Canthal Lines
# Labels: ['ObjectNode'], Name: ≥ 2 points improvement
# Labels: ['SubjectNode'], Name: NCT05882045
# Labels: ['ObjectNode'], Name: AUCτ at steady state
# Labels: ['SubjectNode'], Name: NCT01597245
# Labels: ['SubjectNode'], Name: NCT05562947
# Labels: ['ObjectNode'], Name: Port Delivery System With Ranibizumab
# Labels: ['ObjectNode'], Name: CST at Week 36
# Labels: ['ObjectNode'], Name: CPT at Week 36
# Labels: ['SubjectNode'], Name: NCT01421147
# Labels: ['SubjectNode'], Name: NCT02688647
# Labels: ['ObjectNode'], Name: Percentages of Subjects With SAEs
# Labels: ['ObjectNode'], Name: Age 6-50 years
# Labels: ['SubjectNode'], Name: NCT01113047
# Labels: ['SubjectNode'], Name: NCT05157945
# Labels: ['ObjectNode'], Name: signing of ICF
# Labels: ['SubjectNode'], Name: NCT00894647
# Labels: ['ObjectNode'], Name: study cream
# Labels: ['ObjectNode'], Name: Absolute Change in Non-inflammatory Lesion Counts
# Labels: ['ObjectNode'], Name: Complete clearance of AK lesions
# Labels: ['ObjectNode'], Name: ≥ 10 clinically typical AKs
# Labels: ['ObjectNode'], Name: cryosurgery on 5 to 14 AKs
# Labels: ['ObjectNode'], Name: healed cryosurgery lesions
# Labels: ['SubjectNode'], Name: NCT01592747
# Labels: ['ObjectNode'], Name: Pervasive Developmental Disorder Not Otherwise Specified
# Labels: ['ObjectNode'], Name: Change From Baseline in CCC-2 Syntax Subscale
# Labels: ['ObjectNode'], Name: Change From Baseline in CCC-2 Speech Subscale
# Labels: ['ObjectNode'], Name: Previously Treated With Memantine
# Labels: ['SubjectNode'], Name: NCT06277245
# Labels: ['SubjectNode'], Name: NCT05630547
# Labels: ['ObjectNode'], Name: sNfL levels
# Labels: ['ObjectNode'], Name: Time to onset of 9-HPT
# Labels: ['ObjectNode'], Name: Time to onset of T25-FW
# Labels: ['SubjectNode'], Name: NCT01795547
# Labels: ['ObjectNode'], Name: Investigator's Assessment Questionnaire
# Labels: ['SubjectNode'], Name: NCT01506947
# Labels: ['ObjectNode'], Name: Calcitriol-resistant anemia
# Labels: ['ObjectNode'], Name: Intact-PTH level
# Labels: ['ObjectNode'], Name: serum hemoglobin levels
# Labels: ['SubjectNode'], Name: NCT02589847
# Labels: ['ObjectNode'], Name: Recurrent Clostridium Difficile Infection
# Labels: ['ObjectNode'], Name: RBX2660
# Labels: ['ObjectNode'], Name: CDI-diarrhea free
# Labels: ['SubjectNode'], Name: NCT00369577
# Labels: ['ObjectNode'], Name: Change From Baseline PANSS
# Labels: ['ObjectNode'], Name: CGI-I After Drug Administration
# Labels: ['ObjectNode'], Name: at least 1 item ≥4
# Labels: ['SubjectNode'], Name: NCT00810277
# Labels: ['SubjectNode'], Name: NCT03797677
# Labels: ['ObjectNode'], Name: MND
# Labels: ['SubjectNode'], Name: NCT00504777
# Labels: ['ObjectNode'], Name: EULAR Category
# Labels: ['SubjectNode'], Name: NCT03615677
# Labels: ['ObjectNode'], Name: LX1031
# Labels: ['ObjectNode'], Name: Endoscopic Healing of RE
# Labels: ['ObjectNode'], Name: Gastro Esophageal Reflux Disease-Health Related Quality of Life (GERD-HRQL) score
# Labels: ['ObjectNode'], Name: Capable of understanding protocol
# Labels: ['ObjectNode'], Name: Agree to comply
# Labels: ['SubjectNode'], Name: NCT00079677
# Labels: ['ObjectNode'], Name: nCPAP therapy
# Labels: ['SubjectNode'], Name: NCT05707377
# Labels: ['ObjectNode'], Name: anti- phospholipase A2 receptor (PLA2R) antibody level reduced from baseline to less than 14 RU/ml.
# Labels: ['ObjectNode'], Name: UPCR (based on 24-hour urine collection) ≤ 0.3
# Labels: ['ObjectNode'], Name: stable or improved eGFR
# Labels: ['SubjectNode'], Name: NCT00351377
# Labels: ['ObjectNode'], Name: 6-8 week visit
# Labels: ['SubjectNode'], Name: NCT05357677
# Labels: ['ObjectNode'], Name: DN4 score ≥4
# Labels: ['ObjectNode'], Name: Average PI-NRS score ≥4 and ≤9
# Labels: ['ObjectNode'], Name: Female non-pregnant non-lactating
# Labels: ['SubjectNode'], Name: NCT01139047
# Labels: ['SubjectNode'], Name: NCT01124877
# Labels: ['SubjectNode'], Name: NCT00526877
# Labels: ['SubjectNode'], Name: NCT03821077
# Labels: ['ObjectNode'], Name: Allergovac Poliplus
# Labels: ['ObjectNode'], Name: Combined Symptom and Medication Score
# Labels: ['ObjectNode'], Name: Total number
# Labels: ['ObjectNode'], Name: Patient´s Tolerability assessment using a Likert-type scale
# Labels: ['SubjectNode'], Name: NCT00932477
# Labels: ['ObjectNode'], Name: Artificial Tear Formulation
# Labels: ['ObjectNode'], Name: Biomicroscopy Findings
# Labels: ['ObjectNode'], Name: Mild
# Labels: ['SubjectNode'], Name: NCT01230177
# Labels: ['SubjectNode'], Name: NCT03155347
# Labels: ['SubjectNode'], Name: NCT00853047
# Labels: ['ObjectNode'], Name: Stool Form/Consistency
# Labels: ['ObjectNode'], Name: Sensation of Urgency
# Labels: ['ObjectNode'], Name: Cutaneous Flushing Episodes
# Labels: ['SubjectNode'], Name: NCT01396447
# Labels: ['SubjectNode'], Name: NCT01964547
# Labels: ['ObjectNode'], Name: PASAT Total Score
# Labels: ['ObjectNode'], Name: Score of 21 or over
# Labels: ['SubjectNode'], Name: NCT01892345
# Labels: ['ObjectNode'], Name: Adjudicated ARR
# Labels: ['ObjectNode'], Name: Hauser Ambulation Index
# Labels: ['SubjectNode'], Name: NCT06006247
# Labels: ['SubjectNode'], Name: NCT06111547
# Labels: ['ObjectNode'], Name: AUC of IkT-148009
# Labels: ['ObjectNode'], Name: Cmax of TAF
# Labels: ['ObjectNode'], Name: AUC0-t of TAK-279
# Labels: ['SubjectNode'], Name: NCT01707147
# Labels: ['ObjectNode'], Name: Trajenta
# Labels: ['ObjectNode'], Name: Patients started on Trajenta
# Labels: ['SubjectNode'], Name: NCT01967147
# Labels: ['ObjectNode'], Name: Systane® Balance
# Labels: ['ObjectNode'], Name: TFBUT at Day 35
# Labels: ['ObjectNode'], Name: TOSS Score at Day 35
# Labels: ['ObjectNode'], Name: OSDI Score at Day 35
# Labels: ['ObjectNode'], Name: IDEEL Treatment Effectiveness Score at Day 35
# Labels: ['SubjectNode'], Name: NCT01371747
# Labels: ['SubjectNode'], Name: NCT01395147
# Labels: ['SubjectNode'], Name: NCT01955161
# Labels: ['SubjectNode'], Name: NCT05084261
# Labels: ['SubjectNode'], Name: NCT00856661
# Labels: ['ObjectNode'], Name: Tenecteplase
# Labels: ['ObjectNode'], Name: mRS score 0-2
# Labels: ['ObjectNode'], Name: Modified Neurological Impairment Score (mNIS +7) Composite Score
# Labels: ['SubjectNode'], Name: NCT04014361
# Labels: ['SubjectNode'], Name: NCT06606561
# Labels: ['ObjectNode'], Name: NANOVAE
# Labels: ['ObjectNode'], Name: Single Leg Stance Test
# Labels: ['ObjectNode'], Name: subjects with KOA
# Labels: ['SubjectNode'], Name: NCT02349061
# Labels: ['SubjectNode'], Name: NCT02177461
# Labels: ['ObjectNode'], Name: Incidence of Blood Pressure Abnormalities
# Labels: ['ObjectNode'], Name: Treatment withdrawal rate
# Labels: ['SubjectNode'], Name: NCT01155661
# Labels: ['ObjectNode'], Name: Improvement of sexual function
# Labels: ['SubjectNode'], Name: NCT03738761
# Labels: ['ObjectNode'], Name: Mean Relative Percent Change
# Labels: ['SubjectNode'], Name: NCT05528861
# Labels: ['ObjectNode'], Name: refractory to H1-AH
# Labels: ['SubjectNode'], Name: NCT02394561
# Labels: ['SubjectNode'], Name: NCT04556383
# Labels: ['ObjectNode'], Name: GB002
# Labels: ['SubjectNode'], Name: NCT03227861
# Labels: ['ObjectNode'], Name: (D/C/F/TAF) Once Daily Fixed Dose Combination (FDC) Regimen
# Labels: ['ObjectNode'], Name: safety stopping rules
# Labels: ['SubjectNode'], Name: NCT03372161
# Labels: ['ObjectNode'], Name: Corticosteroid Lumbar Epidural Analgesia
# Labels: ['SubjectNode'], Name: NCT05509361
# Labels: ['ObjectNode'], Name: AK111 Injection
# Labels: ['ObjectNode'], Name: Completed AD-4833/TOMM40_301 study
# Labels: ['SubjectNode'], Name: NCT05424887
# Labels: ['ObjectNode'], Name: AK102
# Labels: ['ObjectNode'], Name: %DLco decrease
# Labels: ['ObjectNode'], Name: at least 50% decrease
# Labels: ['ObjectNode'], Name: Non-elective hospitalization
# Labels: ['SubjectNode'], Name: NCT03363854
# Labels: ['SubjectNode'], Name: NCT00887354
# Labels: ['ObjectNode'], Name: type of hip fracture
# Labels: ['ObjectNode'], Name: baseline inhaled corticosteroid use
# Labels: ['ObjectNode'], Name: duration of prior bisphosphonate use
# Labels: ['SubjectNode'], Name: NCT01190254
# Labels: ['SubjectNode'], Name: NCT04620733
# Labels: ['ObjectNode'], Name: ≥15% Reduction in ALP
# Labels: ['ObjectNode'], Name: total bilirubin ≤ 1.5 times ULN
# Labels: ['ObjectNode'], Name: Shift of ≥ 2 CTCAE Grades
# Labels: ['ObjectNode'], Name: Inadequate Control to or Intolerance to Ursodeoxycholic Acid
# Labels: ['SubjectNode'], Name: NCT03371251
# Labels: ['ObjectNode'], Name: BOS161721
# Labels: ['SubjectNode'], Name: NCT06470451
# Labels: ['ObjectNode'], Name: Topical HyBryte™
# Labels: ['ObjectNode'], Name: mCAILS score
# Labels: ['ObjectNode'], Name: Patch Lesion Response Rates
# Labels: ['ObjectNode'], Name: Plaque Lesion Response Rates
# Labels: ['ObjectNode'], Name: clinical diagnosis of CTCL
# Labels: ['SubjectNode'], Name: NCT00451451
# Labels: ['SubjectNode'], Name: NCT01340651
# Labels: ['SubjectNode'], Name: NCT03765554
# Labels: ['SubjectNode'], Name: NCT00056654
# Labels: ['ObjectNode'], Name: Leuprolide Acetate
# Labels: ['ObjectNode'], Name: prostatic acid phosphatase
# Labels: ['ObjectNode'], Name: Histological diagnosis of prostate cancer
# Labels: ['ObjectNode'], Name: Need for androgen deprivation treatment
# Labels: ['ObjectNode'], Name: Life expectancy of at least 18 months
# Labels: ['SubjectNode'], Name: NCT01907854
# Labels: ['SubjectNode'], Name: NCT00411554
# Labels: ['ObjectNode'], Name: dietary and exercise interventions
# Labels: ['SubjectNode'], Name: NCT03304054
# Labels: ['SubjectNode'], Name: NCT01582854
# Labels: ['ObjectNode'], Name: Post-stroke Cognitive Impairment
# Labels: ['SubjectNode'], Name: NCT06010654
# Labels: ['ObjectNode'], Name: ANZEILAX
# Labels: ['ObjectNode'], Name: Penn State Worry Questionnaire
# Labels: ['SubjectNode'], Name: NCT00809354
# Labels: ['SubjectNode'], Name: NCT04893551
# Labels: ['ObjectNode'], Name: Tilvestamab (BGB149)
# Labels: ['SubjectNode'], Name: NCT01230853
# Labels: ['SubjectNode'], Name: NCT02670551
# Labels: ['SubjectNode'], Name: NCT05707351
# Labels: ['ObjectNode'], Name: Adynovate
# Labels: ['ObjectNode'], Name: Annualized Bleed Rate
# Labels: ['ObjectNode'], Name: Total Number of Infusions
# Labels: ['SubjectNode'], Name: NCT03439254
# Labels: ['SubjectNode'], Name: NCT03728933
# Labels: ['SubjectNode'], Name: NCT01918033
# Labels: ['SubjectNode'], Name: NCT01624233
# Labels: ['SubjectNode'], Name: NCT00787254
# Labels: ['SubjectNode'], Name: NCT01968954
# Labels: ['ObjectNode'], Name: Ozanezumab
# Labels: ['ObjectNode'], Name: RN316
# Labels: ['SubjectNode'], Name: NCT01370733
# Labels: ['ObjectNode'], Name: Transcranial Electromagnetic Treatment
# Labels: ['SubjectNode'], Name: NCT02253654
# Labels: ['ObjectNode'], Name: Blood Transfusions
# Labels: ['SubjectNode'], Name: NCT02760433
# Labels: ['SubjectNode'], Name: NCT03097133
# Labels: ['SubjectNode'], Name: NCT01127633
# Labels: ['SubjectNode'], Name: NCT06011733
# Labels: ['SubjectNode'], Name: NCT01468233
# Labels: ['SubjectNode'], Name: NCT02746133
# Labels: ['ObjectNode'], Name: Pre-Dialysis Participants
# Labels: ['SubjectNode'], Name: NCT01616654
# Labels: ['ObjectNode'], Name: CDX-0159
# Labels: ['SubjectNode'], Name: NCT04072354
# Labels: ['ObjectNode'], Name: PANSS score ≥ 70
# Labels: ['SubjectNode'], Name: NCT06045754
# Labels: ['SubjectNode'], Name: NCT01729754
# Labels: ['SubjectNode'], Name: NCT06478433
# Labels: ['ObjectNode'], Name: Adenectomy
# Labels: ['SubjectNode'], Name: NCT02633033
# Labels: ['ObjectNode'], Name: EDSS=0
# Labels: ['ObjectNode'], Name: relapse during study period
# Labels: ['SubjectNode'], Name: NCT02495233
# Labels: ['SubjectNode'], Name: NCT06540833
# Labels: ['ObjectNode'], Name: ITI-007
# Labels: ['ObjectNode'], Name: PANSS subscale scores
# Labels: ['SubjectNode'], Name: NCT01663233
# Labels: ['ObjectNode'], Name: Change in AS
# Labels: ['ObjectNode'], Name: Not Responding to Amlodipine
# Labels: ['SubjectNode'], Name: NCT02063854
# Labels: ['ObjectNode'], Name: NE-58095 Tablets
# Labels: ['ObjectNode'], Name: Bone Turnover Marker
# Labels: ['SubjectNode'], Name: NCT05462054
# Labels: ['ObjectNode'], Name: STXBP1 Encephalopathy with Epilepsy
# Labels: ['ObjectNode'], Name: Neurodevelopmental Disabilities
# Labels: ['ObjectNode'], Name: calendar age and VABS-II age -equivalent score
# Labels: ['SubjectNode'], Name: NCT02006654
# Labels: ['SubjectNode'], Name: NCT05514054
# Labels: ['ObjectNode'], Name: Imlifidase
# Labels: ['ObjectNode'], Name: Randomization to recurrence or death
# Labels: ['SubjectNode'], Name: NCT00857233
# Labels: ['SubjectNode'], Name: NCT00706654
# Labels: ['SubjectNode'], Name: NCT00385736
# Labels: ['SubjectNode'], Name: NCT00386607
# Labels: ['SubjectNode'], Name: NCT03518073

# %% [markdown]
# ## Step 2: Project the Graph
#
# Graph projection transforms raw data into a structure suitable for GDS algorithms.

# %%
def project_graph(tx):
    query = """
    CALL gds.graph.project(
        'clinicalTrialsGraph',
        ['SubjectNode', 'ObjectNode'],
        {
            RELATIONSHIP: {orientation: 'UNDIRECTED'}
        }
    )
    """
    tx.run(query)
    print("Graph successfully projected with undirected relationships.")

# %% [markdown]
# ## Step 3: Check if the Graph is Projected
#
# Before running the Node Similarity algorithm, ensure the graph is already projected:

# %%
def is_graph_projected(tx):
    query = """
    CALL gds.graph.exists('clinicalTrialsGraph')
    YIELD exists
    RETURN exists
    """
    result = tx.run(query)
    return result.single()["exists"]

# %% [markdown]
# ## Step 4: Run Node Similarity Algorithm
#
# The Node Similarity algorithm compares nodes based on their shared neighbors.
# (Uses Jaccard Similarity)

# %%
# Function to find similar trials using GDS node similarity
def find_similar_trials(tx, trial_id):
    query = f"""
    CALL gds.nodeSimilarity.stream('clinicalTrialsGraph')
    YIELD node1, node2, similarity
    WHERE gds.util.asNode(node1).name = $trial_id
      AND gds.util.asNode(node1):SubjectNode
      AND gds.util.asNode(node2):SubjectNode
    RETURN gds.util.asNode(node2).name AS similarTrial, similarity
    ORDER BY similarity DESC
    LIMIT 10
    """
    print(f"Executing similarity query for trial ID: {trial_id}")
    result = tx.run(query, trial_id=trial_id)
    results = [{"trial": record["similarTrial"], "similarity": record["similarity"]} for record in result]
    print(f"Results: {results}")
    return results

# %%
# Function to drop and re-project the graph
def reproject_graph(tx):
    query = """
    CALL gds.graph.drop('clinicalTrialsGraph', false)
    """
    tx.run(query)
    print("Dropped existing graph projection.")
    project_graph(tx)
    print("Graph re-projected successfully.")


# Function to check if a node exists in the graph
def check_node_exists(tx, node_name, label):
    query = f"""
    MATCH (n:{label} {{name: TRIM($node_name)}})
    RETURN COUNT(n) > 0 AS exists
    """
    print(f"Checking existence of node: {node_name.strip()}")
    result = tx.run(query, node_name=node_name.strip())
    exists = result.single()["exists"]
    print(f"Node exists: {exists}")
    return exists

# %% [markdown]
# ## for single input (NCT Number)

# %%
# Main script to query for similar trials
def main():
    driver = GraphDatabase.driver(URI, auth=AUTH)

    with driver.session() as session:
        # Re-project the graph to ensure the correct structure
        reproject_graph(session)

        # Get input from user
        trial_id = input("Enter the trial ID (e.g., NCT00752622): ")

        # Check if the node exists
        node_exists = session.read_transaction(check_node_exists, trial_id, 'SubjectNode')
        if not node_exists:
            print(f"Node '{trial_id}' does not exist in the graph. Please enter a valid trial ID.")
            return

        # Find similar trials
        print(f"Finding trials similar to {trial_id}...")
        similar_trials = session.read_transaction(find_similar_trials, trial_id)

        if similar_trials:
            print("Top 10 similar trials:")
            for i, trial in enumerate(similar_trials, 1):
                print(f"{i}. Trial ID: {trial['trial']}, Similarity: {trial['similarity']:.4f}")
        else:
            print("No similar trials found.")
    driver.close()

if __name__ == "__main__":
    main()
# Out:
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated field from a procedure. ('schema' returned by 'gds.graph.drop' is deprecated.)} {position: line: 2, column: 1, offset: 5} for query: "\n    CALL gds.graph.drop('clinicalTrialsGraph', false)\n    "
# Dropped existing graph projection.
# Graph successfully projected with undirected relationships.
# Graph re-projected successfully.
# Enter the trial ID (e.g., NCT00752622): NCT00385736
# <ipython-input-39-1150d3b771c5>:13: DeprecationWarning: read_transaction has been renamed to execute_read
#   node_exists = session.read_transaction(check_node_exists, trial_id, 'SubjectNode')
# Checking existence of node: NCT00385736
# Node exists: True
# Finding trials similar to NCT00385736...
# <ipython-input-39-1150d3b771c5>:20: DeprecationWarning: read_transaction has been renamed to execute_read
#   similar_trials = session.read_transaction(find_similar_trials, trial_id)
# Executing similarity query for trial ID: NCT00385736
# Results: [{'trial': 'NCT03029143', 'similarity': 0.625}, {'trial': 'NCT00408629', 'similarity': 0.5}, {'trial': 'NCT01482884', 'similarity': 0.5}, {'trial': 'NCT02289417', 'similarity': 0.5}, {'trial': 'NCT05731128', 'similarity': 0.5}, {'trial': 'NCT00659802', 'similarity': 0.4444444444444444}, {'trial': 'NCT01620255', 'similarity': 0.4444444444444444}, {'trial': 'NCT00488631', 'similarity': 0.4444444444444444}, {'trial': 'NCT02065557', 'similarity': 0.4444444444444444}, {'trial': 'NCT03221036', 'similarity': 0.4}]
# Top 10 similar trials:
# 1. Trial ID: NCT03029143, Similarity: 0.6250
# 2. Trial ID: NCT00408629, Similarity: 0.5000
# 3. Trial ID: NCT01482884, Similarity: 0.5000
# 4. Trial ID: NCT02289417, Similarity: 0.5000
# 5. Trial ID: NCT05731128, Similarity: 0.5000
# 6. Trial ID: NCT00659802, Similarity: 0.4444
# 7. Trial ID: NCT01620255, Similarity: 0.4444
# 8. Trial ID: NCT00488631, Similarity: 0.4444
# 9. Trial ID: NCT02065557, Similarity: 0.4444
# 10. Trial ID: NCT03221036, Similarity: 0.4000

# %% [markdown]
# ## For the given 3 input NCT Numbers

# %%
# Main script to query for similar trials
def main():
    driver = GraphDatabase.driver(URI, auth=AUTH)

    # Main script to query for similar trials
def main():
    driver = GraphDatabase.driver(URI, auth=AUTH)

    with driver.session() as session:
        # Re-project the graph to ensure the correct structure
        reproject_graph(session)

        # Get input for 3 trial IDs from the user
        trial_ids = input("Enter 3 trial IDs separated by commas (e.g., NCT00752622,NCT00812345,NCT00998765): ").split(',')
        trial_ids = [trial_id.strip() for trial_id in trial_ids if trial_id.strip()]

        if len(trial_ids) != 3:
            print("Please enter exactly 3 trial IDs.")
            return

        for trial_id in trial_ids:
            print(f"\nProcessing Trial ID: {trial_id}")

            # Check if the node exists
            node_exists = session.read_transaction(check_node_exists, trial_id, 'SubjectNode')
            if not node_exists:
                print(f"Node '{trial_id}' does not exist in the graph. Please enter a valid trial ID.")
                continue

            # Find similar trials
            print(f"Finding trials similar to {trial_id}...")
            similar_trials = session.read_transaction(find_similar_trials, trial_id)

            if similar_trials:
                print("Top 10 similar trials:")
                for i, trial in enumerate(similar_trials, 1):
                    print(f"{i}. Trial ID: {trial['trial']}, Similarity: {trial['similarity']:.4f}")
            else:
                print("No similar trials found.")

    driver.close()

if __name__ == "__main__":
    main()
# Out:
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated field from a procedure. ('schema' returned by 'gds.graph.drop' is deprecated.)} {position: line: 2, column: 1, offset: 5} for query: "\n    CALL gds.graph.drop('clinicalTrialsGraph', false)\n    "
# Dropped existing graph projection.
# Graph successfully projected with undirected relationships.
# Graph re-projected successfully.
# Enter 3 trial IDs separated by commas (e.g., NCT00752622,NCT00812345,NCT00998765): NCT00385736,NCT00386607,NCT03518073
#
# Processing Trial ID: NCT00385736
# Checking existence of node: NCT00385736
# Node exists: True
# <ipython-input-40-3f807c1fc58d>:25: DeprecationWarning: read_transaction has been renamed to execute_read
#   node_exists = session.read_transaction(check_node_exists, trial_id, 'SubjectNode')
# Finding trials similar to NCT00385736...
# Executing similarity query for trial ID: NCT00385736
# <ipython-input-40-3f807c1fc58d>:32: DeprecationWarning: read_transaction has been renamed to execute_read
#   similar_trials = session.read_transaction(find_similar_trials, trial_id)
# Results: [{'trial': 'NCT03029143', 'similarity': 0.625}, {'trial': 'NCT00408629', 'similarity': 0.5}, {'trial': 'NCT01482884', 'similarity': 0.5}, {'trial': 'NCT02289417', 'similarity': 0.5}, {'trial': 'NCT05731128', 'similarity': 0.5}, {'trial': 'NCT00659802', 'similarity': 0.4444444444444444}, {'trial': 'NCT01620255', 'similarity': 0.4444444444444444}, {'trial': 'NCT00488631', 'similarity': 0.4444444444444444}, {'trial': 'NCT02065557', 'similarity': 0.4444444444444444}, {'trial': 'NCT03221036', 'similarity': 0.4}]
# Top 10 similar trials:
# 1. Trial ID: NCT03029143, Similarity: 0.6250
# 2. Trial ID: NCT00408629, Similarity: 0.5000
# 3. Trial ID: NCT01482884, Similarity: 0.5000
# 4. Trial ID: NCT02289417, Similarity: 0.5000
# 5. Trial ID: NCT05731128, Similarity: 0.5000
# 6. Trial ID: NCT00659802, Similarity: 0.4444
# 7. Trial ID: NCT01620255, Similarity: 0.4444
# 8. Trial ID: NCT00488631, Similarity: 0.4444
# 9. Trial ID: NCT02065557, Similarity: 0.4444
# 10. Trial ID: NCT03221036, Similarity: 0.4000
#
# Processing Trial ID: NCT00386607
# Checking existence of node: NCT00386607
# Node exists: True
# Finding trials similar to NCT00386607...
# Executing similarity query for trial ID: NCT00386607
# Results: [{'trial': 'NCT00402103', 'similarity': 0.3}, {'trial': 'NCT00923091', 'similarity': 0.25}, {'trial': 'NCT00281580', 'similarity': 0.2222222222222222}, {'trial': 'NCT01456169', 'similarity': 0.2}, {'trial': 'NCT00841672', 'similarity': 0.2}, {'trial': 'NCT00698646', 'similarity': 0.19047619047619047}, {'trial': 'NCT00435162', 'similarity': 0.18181818181818182}, {'trial': 'NCT01204398', 'similarity': 0.18181818181818182}, {'trial': 'NCT00151775', 'similarity': 0.18181818181818182}, {'trial': 'NCT06174766', 'similarity': 0.18181818181818182}]
# Top 10 similar trials:
# 1. Trial ID: NCT00402103, Similarity: 0.3000
# 2. Trial ID: NCT00923091, Similarity: 0.2500
# 3. Trial ID: NCT00281580, Similarity: 0.2222
# 4. Trial ID: NCT01456169, Similarity: 0.2000
# 5. Trial ID: NCT00841672, Similarity: 0.2000
# 6. Trial ID: NCT00698646, Similarity: 0.1905
# 7. Trial ID: NCT00435162, Similarity: 0.1818
# 8. Trial ID: NCT01204398, Similarity: 0.1818
# 9. Trial ID: NCT00151775, Similarity: 0.1818
# 10. Trial ID: NCT06174766, Similarity: 0.1818
#
# Processing Trial ID: NCT03518073
# Checking existence of node: NCT03518073
# Node exists: True
# Finding trials similar to NCT03518073...
# Executing similarity query for trial ID: NCT03518073
# Results: [{'trial': 'NCT00762411', 'similarity': 0.42857142857142855}, {'trial': 'NCT00477659', 'similarity': 0.42857142857142855}, {'trial': 'NCT00428090', 'similarity': 0.42857142857142855}, {'trial': 'NCT02754830', 'similarity': 0.42857142857142855}, {'trial': 'NCT00843518', 'similarity': 0.4}, {'trial': 'NCT05310071', 'similarity': 0.3333333333333333}, {'trial': 'NCT01849055', 'similarity': 0.3333333333333333}, {'trial': 'NCT04994483', 'similarity': 0.2857142857142857}, {'trial': 'NCT02091362', 'similarity': 0.2857142857142857}, {'trial': 'NCT02670083', 'similarity': 0.2857142857142857}]
# Top 10 similar trials:
# 1. Trial ID: NCT00762411, Similarity: 0.4286
# 2. Trial ID: NCT00477659, Similarity: 0.4286
# 3. Trial ID: NCT00428090, Similarity: 0.4286
# 4. Trial ID: NCT02754830, Similarity: 0.4286
# 5. Trial ID: NCT00843518, Similarity: 0.4000
# 6. Trial ID: NCT05310071, Similarity: 0.3333
# 7. Trial ID: NCT01849055, Similarity: 0.3333
# 8. Trial ID: NCT04994483, Similarity: 0.2857
# 9. Trial ID: NCT02091362, Similarity: 0.2857
# 10. Trial ID: NCT02670083, Similarity: 0.2857

# %% [markdown]
# # Results
#
# ## NCT ID: NCT00385736
#
# Recommendations:
#
# 1. Trial ID: NCT03029143, Similarity: 0.6250
# 2. Trial ID: NCT00408629, Similarity: 0.5000
# 3. Trial ID: NCT01482884, Similarity: 0.5000
# 4. Trial ID: NCT02289417, Similarity: 0.5000
# 5. Trial ID: NCT05731128, Similarity: 0.5000
# 6. Trial ID: NCT00659802, Similarity: 0.4444
# 7. Trial ID: NCT01620255, Similarity: 0.4444
# 8. Trial ID: NCT00488631, Similarity: 0.4444
# 9. Trial ID: NCT02065557, Similarity: 0.4444
# 10. Trial ID: NCT03221036, Similarity: 0.4000
#
#
# ## NCT ID: NCT00386607
#
# Recommendations:
#
# 1. Trial ID: NCT00402103, Similarity: 0.3000
# 2. Trial ID: NCT00923091, Similarity: 0.2500
# 3. Trial ID: NCT00281580, Similarity: 0.2222
# 4. Trial ID: NCT01456169, Similarity: 0.2000
# 5. Trial ID: NCT00841672, Similarity: 0.2000
# 6. Trial ID: NCT00698646, Similarity: 0.1905
# 7. Trial ID: NCT00435162, Similarity: 0.1818
# 8. Trial ID: NCT01204398, Similarity: 0.1818
# 9. Trial ID: NCT00151775, Similarity: 0.1818
# 10. Trial ID: NCT06174766, Similarity: 0.1818
#
# ## NCT ID: NCT03518073
#
# Recommendations:
#
# 1. Trial ID: NCT00762411, Similarity: 0.4286
# 2. Trial ID: NCT00477659, Similarity: 0.4286
# 3. Trial ID: NCT00428090, Similarity: 0.4286
# 4. Trial ID: NCT02754830, Similarity: 0.4286
# 5. Trial ID: NCT00843518, Similarity: 0.4000
# 6. Trial ID: NCT05310071, Similarity: 0.3333
# 7. Trial ID: NCT01849055, Similarity: 0.3333
# 8. Trial ID: NCT04994483, Similarity: 0.2857
# 9. Trial ID: NCT02091362, Similarity: 0.2857
# 10. Trial ID: NCT02670083, Similarity: 0.2857
